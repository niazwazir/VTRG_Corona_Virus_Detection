# %%
# !git clone https://github.com/niazwazir/VTRG_Corona_Virus_Detection.git
# Out:
# Cloning into 'VTRG_Corona_Virus_Detection'...
# remote: Enumerating objects: 179, done.
# remote: Counting objects: 100% (179/179), done.
# remote: Compressing objects: 100% (159/159), done.
# remote: Total 179 (delta 16), reused 173 (delta 14), pack-reused 0
# Receiving objects: 100% (179/179), 33.98 MiB | 4.56 MiB/s, done.
# Resolving deltas: 100% (16/16), done.

# %%
cd VTRG_Corona_Virus_Detection/
# Out:
# /content/VTRG_Corona_Virus_Detection

# %%
#importing the necessary packages
import numpy as np
import cv2
import os
from imutils import paths
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import VGG16
from tensorflow.keras.layers import AveragePooling2D
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Input
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import to_categorical
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

# %%
#setting arguments 
args = {"dataset": "./dataset",
        "model": "corona.model"
       }

# %%
"""initializing the initial learning rate, epochs to train
   and batch size"""
learningRate = 1e-3
epochs = 61
batchSize = 8

# %%
"""listing out the images in the dataset folder, then initializing
   the list of data (images) and class images"""
imagePaths = list(paths.list_images(args["dataset"]))
data = []
labels = []

#looping over the images paths
for imagePath in imagePaths:
    
    #extracting the class label from image paths
    label = imagePath.split(os.path.sep)[-2]

    """loading the images, changing color channels and resizing it to be a fixed
       224x224 pixels"""
    image = cv2.imread(imagePath)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    image = cv2.resize(image, (224, 224))

    #updating the data and labels lists
    data.append(image)
    labels.append(label)

"""converting the data and labels to NumPy arrays and scaling the pixel
   intensities to the range [0, 255]"""
data = np.array(data) / 255.0
labels = np.array(labels)

# %%
#using one-hot encoding on labels
lb = LabelBinarizer()
labels = lb.fit_transform(labels)
labels = to_categorical(labels)

"""splitting the data into training and testing using 80% of
   the data for training and 20% for testing"""
(trainX, testX, trainY, testY) = train_test_split(data, labels, test_size=0.20, stratify=labels, 
                                                  random_state=42)

#initializing the training data augmentation object
trainAug = ImageDataGenerator(
    rotation_range=15,
    fill_mode="nearest")

# %%
#loading the VGG16 network, ensuring the head FC layer sets are left
baseModel = VGG16(weights="imagenet", include_top=False, input_tensor=Input(shape=(224, 224, 3)))

"""constructing the main model that will be placed on top of the
   the base model"""
mainModel = baseModel.output
mainModel = AveragePooling2D(pool_size=(4, 4))(mainModel)
mainModel = Flatten(name="flatten")(mainModel)
mainModel = Dense(64, activation="relu")(mainModel)
mainModel = Dropout(0.5)(mainModel)
mainModel = Dense(2, activation="softmax")(mainModel)

#lace the head FC model on top of the base model (actual model)
model = Model(inputs=baseModel.input, outputs=mainModel)

"""looping over all layers in the base model and freeze them so they will 
   not be updated during the first training process"""
for layer in baseModel.layers:
    layer.trainable = False
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58892288/58889256 [==============================] - 2s 0us/step

# %%
import keras
import tensorflow as tf
# Out:
# Using TensorFlow backend.

# %%
tf.keras.utils.plot_model(model, 'Wazir_first_model.png')

# %%
#compiling up the model
optimizer = Adam(lr=learningRate, decay=learningRate / epochs)
model.compile(loss="binary_crossentropy", optimizer=optimizer, metrics=["accuracy"])

#training the head of the network
networkHead = model.fit_generator(
    trainAug.flow(trainX, trainY, batch_size=batchSize),
    steps_per_epoch=len(trainX) // batchSize,
    validation_data=(testX, testY),
    validation_steps=len(testX) // batchSize,
    epochs=epochs)
# Out:
# WARNING:tensorflow:From <ipython-input-11-da3f3de48a6e>:10: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# Epoch 1/61
# 11/11 [==============================] - 4s 344ms/step - loss: 0.8743 - accuracy: 0.4205 - val_loss: 0.6754 - val_accuracy: 0.5652
# Epoch 2/61
# 11/11 [==============================] - 1s 94ms/step - loss: 0.7085 - accuracy: 0.5610 - val_loss: 0.6499 - val_accuracy: 0.6957
# Epoch 3/61
# 11/11 [==============================] - 1s 93ms/step - loss: 0.7144 - accuracy: 0.4634 - val_loss: 0.6204 - val_accuracy: 0.7391
# Epoch 4/61
# 11/11 [==============================] - 1s 91ms/step - loss: 0.6542 - accuracy: 0.6220 - val_loss: 0.5997 - val_accuracy: 0.7391
# Epoch 5/61
# 11/11 [==============================] - 1s 91ms/step - loss: 0.5939 - accuracy: 0.7195 - val_loss: 0.5741 - val_accuracy: 0.8261
# Epoch 6/61
# 11/11 [==============================] - 1s 93ms/step - loss: 0.4872 - accuracy: 0.8293 - val_loss: 0.5528 - val_accuracy: 0.7826
# Epoch 7/61
# 11/11 [==============================] - 1s 91ms/step - loss: 0.5932 - accuracy: 0.6707 - val_loss: 0.5575 - val_accuracy: 0.8261
# Epoch 8/61
# 11/11 [==============================] - 1s 92ms/step - loss: 0.4944 - accuracy: 0.8171 - val_loss: 0.5051 - val_accuracy: 0.8261
# Epoch 9/61
# 11/11 [==============================] - 1s 91ms/step - loss: 0.4643 - accuracy: 0.8659 - val_loss: 0.4826 - val_accuracy: 0.8696
# Epoch 10/61
# 11/11 [==============================] - 1s 91ms/step - loss: 0.4222 - accuracy: 0.9024 - val_loss: 0.4581 - val_accuracy: 0.8696
# Epoch 11/61
# 11/11 [==============================] - 1s 92ms/step - loss: 0.4002 - accuracy: 0.9512 - val_loss: 0.4376 - val_accuracy: 0.8261
# Epoch 12/61
# 11/11 [==============================] - 1s 89ms/step - loss: 0.3673 - accuracy: 0.8659 - val_loss: 0.4215 - val_accuracy: 0.8696
# Epoch 13/61
# 11/11 [==============================] - 1s 96ms/step - loss: 0.3707 - accuracy: 0.8864 - val_loss: 0.4122 - val_accuracy: 0.8261
# Epoch 14/61
# 11/11 [==============================] - 1s 99ms/step - loss: 0.3952 - accuracy: 0.8537 - val_loss: 0.4020 - val_accuracy: 0.8696
# Epoch 15/61
# 11/11 [==============================] - 1s 92ms/step - loss: 0.3619 - accuracy: 0.8902 - val_loss: 0.3964 - val_accuracy: 0.9130
# Epoch 16/61
# 11/11 [==============================] - 1s 92ms/step - loss: 0.2871 - accuracy: 0.9146 - val_loss: 0.3719 - val_accuracy: 0.8696
# Epoch 17/61
# 11/11 [==============================] - 1s 91ms/step - loss: 0.2963 - accuracy: 0.9268 - val_loss: 0.3716 - val_accuracy: 0.8696
# Epoch 18/61
# 11/11 [==============================] - 1s 93ms/step - loss: 0.2523 - accuracy: 0.9634 - val_loss: 0.3676 - val_accuracy: 0.9130
# Epoch 19/61
# 11/11 [==============================] - 1s 92ms/step - loss: 0.3385 - accuracy: 0.9512 - val_loss: 0.3659 - val_accuracy: 0.8261
# Epoch 20/61
# 11/11 [==============================] - 1s 93ms/step - loss: 0.2089 - accuracy: 0.9512 - val_loss: 0.3552 - val_accuracy: 0.9130
# Epoch 21/61
# 11/11 [==============================] - 1s 91ms/step - loss: 0.2049 - accuracy: 0.9756 - val_loss: 0.3540 - val_accuracy: 0.9130
# Epoch 22/61
# 11/11 [==============================] - 1s 92ms/step - loss: 0.2310 - accuracy: 0.9634 - val_loss: 0.3469 - val_accuracy: 0.9130
# Epoch 23/61
# 11/11 [==============================] - 1s 92ms/step - loss: 0.1723 - accuracy: 0.9756 - val_loss: 0.3449 - val_accuracy: 0.9130
# Epoch 24/61
# 11/11 [==============================] - 1s 89ms/step - loss: 0.1494 - accuracy: 0.9878 - val_loss: 0.3421 - val_accuracy: 0.9130
# Epoch 25/61
# 11/11 [==============================] - 1s 95ms/step - loss: 0.2052 - accuracy: 0.9432 - val_loss: 0.3439 - val_accuracy: 0.9130
# Epoch 26/61
# 11/11 [==============================] - 1s 98ms/step - loss: 0.1924 - accuracy: 0.9512 - val_loss: 0.3409 - val_accuracy: 0.9130
# Epoch 27/61
# 11/11 [==============================] - 1s 94ms/step - loss: 0.2123 - accuracy: 0.9512 - val_loss: 0.3443 - val_accuracy: 0.9130
# Epoch 28/61
# 11/11 [==============================] - 1s 93ms/step - loss: 0.1513 - accuracy: 0.9634 - val_loss: 0.3432 - val_accuracy: 0.9130
# Epoch 29/61
# 11/11 [==============================] - 1s 92ms/step - loss: 0.1809 - accuracy: 0.9756 - val_loss: 0.3448 - val_accuracy: 0.9130
# Epoch 30/61
# 11/11 [==============================] - 1s 92ms/step - loss: 0.1398 - accuracy: 0.9634 - val_loss: 0.3451 - val_accuracy: 0.9130
# Epoch 31/61
# 11/11 [==============================] - 1s 93ms/step - loss: 0.1415 - accuracy: 0.9756 - val_loss: 0.3501 - val_accuracy: 0.9130
# Epoch 32/61
# 11/11 [==============================] - 1s 92ms/step - loss: 0.1587 - accuracy: 0.9634 - val_loss: 0.3489 - val_accuracy: 0.9130
# Epoch 33/61
# 11/11 [==============================] - 1s 93ms/step - loss: 0.1073 - accuracy: 0.9756 - val_loss: 0.3512 - val_accuracy: 0.9130
# Epoch 34/61
# 11/11 [==============================] - 1s 93ms/step - loss: 0.1731 - accuracy: 0.9634 - val_loss: 0.3490 - val_accuracy: 0.9130
# Epoch 35/61
# 11/11 [==============================] - 1s 92ms/step - loss: 0.1409 - accuracy: 0.9634 - val_loss: 0.3531 - val_accuracy: 0.9130
# Epoch 36/61
# 11/11 [==============================] - 1s 91ms/step - loss: 0.1386 - accuracy: 0.9756 - val_loss: 0.3600 - val_accuracy: 0.8696
# Epoch 37/61
# 11/11 [==============================] - 1s 96ms/step - loss: 0.1256 - accuracy: 0.9773 - val_loss: 0.3559 - val_accuracy: 0.9130
# Epoch 38/61
# 11/11 [==============================] - 1s 100ms/step - loss: 0.1172 - accuracy: 0.9878 - val_loss: 0.3760 - val_accuracy: 0.8696
# Epoch 39/61
# 11/11 [==============================] - 1s 91ms/step - loss: 0.1529 - accuracy: 0.9512 - val_loss: 0.3791 - val_accuracy: 0.9130
# Epoch 40/61
# 11/11 [==============================] - 1s 91ms/step - loss: 0.0948 - accuracy: 0.9878 - val_loss: 0.3819 - val_accuracy: 0.8696
# Epoch 41/61
# 11/11 [==============================] - 1s 92ms/step - loss: 0.1056 - accuracy: 0.9634 - val_loss: 0.3799 - val_accuracy: 0.9130
# Epoch 42/61
# 11/11 [==============================] - 1s 92ms/step - loss: 0.0975 - accuracy: 0.9756 - val_loss: 0.3859 - val_accuracy: 0.8696
# Epoch 43/61
# 11/11 [==============================] - 1s 91ms/step - loss: 0.1511 - accuracy: 0.9512 - val_loss: 0.3867 - val_accuracy: 0.9130
# Epoch 44/61
# 11/11 [==============================] - 1s 92ms/step - loss: 0.1685 - accuracy: 0.9512 - val_loss: 0.3833 - val_accuracy: 0.9130
# Epoch 45/61
# 11/11 [==============================] - 1s 91ms/step - loss: 0.1160 - accuracy: 0.9756 - val_loss: 0.3942 - val_accuracy: 0.9130
# Epoch 46/61
# 11/11 [==============================] - 1s 93ms/step - loss: 0.0923 - accuracy: 1.0000 - val_loss: 0.4035 - val_accuracy: 0.9130
# Epoch 47/61
# 11/11 [==============================] - 1s 92ms/step - loss: 0.0953 - accuracy: 0.9878 - val_loss: 0.4066 - val_accuracy: 0.8696
# Epoch 48/61
# 11/11 [==============================] - 1s 92ms/step - loss: 0.0922 - accuracy: 0.9756 - val_loss: 0.4035 - val_accuracy: 0.8696
# Epoch 49/61
# 11/11 [==============================] - 1s 94ms/step - loss: 0.0735 - accuracy: 1.0000 - val_loss: 0.4186 - val_accuracy: 0.8696
# Epoch 50/61
# 11/11 [==============================] - 1s 99ms/step - loss: 0.0838 - accuracy: 0.9756 - val_loss: 0.4056 - val_accuracy: 0.9130
# Epoch 51/61
# 11/11 [==============================] - 1s 93ms/step - loss: 0.0822 - accuracy: 0.9756 - val_loss: 0.4017 - val_accuracy: 0.8696
# Epoch 52/61
# 11/11 [==============================] - 1s 92ms/step - loss: 0.0609 - accuracy: 1.0000 - val_loss: 0.4028 - val_accuracy: 0.9130
# Epoch 53/61
# 11/11 [==============================] - 1s 93ms/step - loss: 0.1039 - accuracy: 0.9878 - val_loss: 0.4093 - val_accuracy: 0.9130
# Epoch 54/61
# 11/11 [==============================] - 1s 93ms/step - loss: 0.0683 - accuracy: 0.9756 - val_loss: 0.4144 - val_accuracy: 0.9130
# Epoch 55/61
# 11/11 [==============================] - 1s 93ms/step - loss: 0.0761 - accuracy: 1.0000 - val_loss: 0.4112 - val_accuracy: 0.9130
# Epoch 56/61
# 11/11 [==============================] - 1s 92ms/step - loss: 0.0637 - accuracy: 1.0000 - val_loss: 0.4173 - val_accuracy: 0.8696
# Epoch 57/61
# 11/11 [==============================] - 1s 91ms/step - loss: 0.0640 - accuracy: 1.0000 - val_loss: 0.4303 - val_accuracy: 0.8696
# Epoch 58/61
# 11/11 [==============================] - 1s 93ms/step - loss: 0.0698 - accuracy: 0.9878 - val_loss: 0.4366 - val_accuracy: 0.8696
# Epoch 59/61
# 11/11 [==============================] - 1s 92ms/step - loss: 0.0822 - accuracy: 0.9878 - val_loss: 0.4398 - val_accuracy: 0.8696
# Epoch 60/61
# 11/11 [==============================] - 1s 92ms/step - loss: 0.0735 - accuracy: 1.0000 - val_loss: 0.4399 - val_accuracy: 0.9130
# Epoch 61/61
# 11/11 [==============================] - 1s 96ms/step - loss: 0.0863 - accuracy: 0.9886 - val_loss: 0.4574 - val_accuracy: 0.8696

# %%
#making predictions on the testing data
predIndexs = model.predict(testX, batch_size=batchSize)

"""for each image in the testing data we need to find the index of the
   label with corresponding largest predicted probability"""
predIndexs = np.argmax(predIndexs, axis=1)

#printing classification report
print(classification_report(testY.argmax(axis=1), predIndexs, target_names=lb.classes_))
# Out:
#               precision    recall  f1-score   support
#
#     infected       0.92      0.85      0.88        13
#   uninfected       0.82      0.90      0.86        10
#
#     accuracy                           0.87        23
#    macro avg       0.87      0.87      0.87        23
# weighted avg       0.87      0.87      0.87        23

# %%
#computing the confusion matrix and use it to derive the raw accuracy
cm = confusion_matrix(testY.argmax(axis=1), predIndexs)
total = sum(sum(cm))
acc = (cm[0, 0] + cm[1, 1]) / total

# printing confusion matrix, accuracy
print(cm)
print("acc: {:.4f}".format(acc))
# Out:
# [[11  2]
#  [ 1  9]]
# acc: 0.8696

# %%
#saving the model
model.save(args["model"])
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/resource_variable_ops.py:1817: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# INFO:tensorflow:Assets written to: corona.model/assets

# %%
# !ls
# Out:
# corona.model  output	 train-model.ipynb
# dataset       README.md  Wazir_first_model.png

# %%
#testing out the model
import tensorflow as tf

#loading the model
model = tf.keras.models.load_model("corona.model")

# %%
testImage = cv2.imread("./dataset/infected/A.jpeg") #For Positive Case
#testImage = cv2.imread("./dataset/infected/B.jpeg") #For Negative Case

# %%
#preprocessing the test image
image = cv2.cvtColor(testImage, cv2.COLOR_BGR2RGB)
image = cv2.resize(image, (224, 224))
image = image.astype("float") / 255.0

# %%
#reshaping the numpy array according to image size
image = np.array(image).reshape(1,224,224,3)

#doing prediction on test image
pred = model.predict(image)
pred = pred.argmax(axis=1)[0]

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

# %%
#putting text on image and showing output image
imageText = "Corona Negative" if pred == 1 else "Corona Positive"
color = (0, 255, 0) if pred == 1 else (0, 0, 255)

testImage = cv2.resize(testImage, (424, 424))
cv2.putText(testImage, imageText, (3, 20), cv2.FONT_ITALIC, 0.5,color, 2)
cv2_imshow(testImage)
# Out:
# <PIL.Image.Image image mode=RGB size=424x424 at 0x7F91AB92A400>
