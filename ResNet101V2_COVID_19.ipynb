# %%
# !git clone https://github.com/niazwazir/VTRG_Corona_Virus_Detection.git
# Out:
# Cloning into 'VTRG_Corona_Virus_Detection'...
# remote: Enumerating objects: 208, done.
# remote: Counting objects: 100% (208/208), done.
# remote: Compressing objects: 100% (188/188), done.
# remote: Total 208 (delta 27), reused 174 (delta 14), pack-reused 0
# Receiving objects: 100% (208/208), 42.52 MiB | 10.69 MiB/s, done.
# Resolving deltas: 100% (27/27), done.

# %%
cd VTRG_Corona_Virus_Detection/
# Out:
# /content/VTRG_Corona_Virus_Detection

# %%
#importing the necessary packages
import numpy as np
import cv2
import os
from imutils import paths
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import VGG16, Xception, ResNet50, VGG19, DenseNet121, DenseNet169, DenseNet201, ResNet101, ResNet101V2, ResNet152, ResNet152V2, ResNet50V2
from tensorflow.keras.layers import AveragePooling2D
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Input
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import to_categorical
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

# %%
#setting arguments 
args = {"dataset": "./dataset",
        "model": "corona.model"
       }

# %%
"""initializing the initial learning rate, epochs to train
   and batch size"""
learningRate = 1e-3
epochs = 500
batchSize = 8

# %%
"""listing out the images in the dataset folder, then initializing
   the list of data (images) and class images"""
imagePaths = list(paths.list_images(args["dataset"]))
data = []
labels = []

#looping over the images paths
for imagePath in imagePaths:
    
    #extracting the class label from image paths
    label = imagePath.split(os.path.sep)[-2]

    """loading the images, changing color channels and resizing it to be a fixed
       224x224 pixels"""
    image = cv2.imread(imagePath)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    image = cv2.resize(image, (224, 224))

    #updating the data and labels lists
    data.append(image)
    labels.append(label)

"""converting the data and labels to NumPy arrays and scaling the pixel
   intensities to the range [0, 255]"""
data = np.array(data) / 255.0
labels = np.array(labels)

# %%
#using one-hot encoding on labels
lb = LabelBinarizer()
labels = lb.fit_transform(labels)
labels = to_categorical(labels)

"""splitting the data into training and testing using 80% of
   the data for training and 20% for testing"""
(trainX, testX, trainY, testY) = train_test_split(data, labels, test_size=0.20, stratify=labels, 
                                                  random_state=42)

#initializing the training data augmentation object
trainAug = ImageDataGenerator(
    rotation_range=15,
    fill_mode="nearest")

# %%
#loading the VGG16 network, ensuring the head FC layer sets are left
#baseModel = VGG16(weights="imagenet", include_top=False, input_tensor=Input(shape=(224, 224, 3)))
#baseModel = VGG19(weights="imagenet", include_top=False, input_tensor=Input(shape=(224, 224, 3)))
#baseModel = DenseNet121(weights="imagenet", include_top=False, input_tensor=Input(shape=(224, 224, 3)))
#baseModel = DenseNet169(weights="imagenet", include_top=False, input_tensor=Input(shape=(224, 224, 3)))
#baseModel = DenseNet201(weights="imagenet", include_top=False, input_tensor=Input(shape=(224, 224, 3)))
#baseModel =  ResNet101(weights="imagenet", include_top=False, input_tensor=Input(shape=(224, 224, 3)))
baseModel =  ResNet101V2(weights="imagenet", include_top=False, input_tensor=Input(shape=(224, 224, 3)))
#baseModel = Xception(weights="imagenet", include_top=False, input_tensor=Input(shape=(224, 224, 3)))
#baseModel = ResNet50(weights="imagenet", include_top=False, input_tensor=Input(shape=(224, 224, 3)))
"""constructing the main model that will be placed on top of the
   the base model"""
mainModel = baseModel.output

mainModel = AveragePooling2D(pool_size=(4, 4))(mainModel)
mainModel = Flatten(name="flatten")(mainModel)
mainModel = Dense(64, activation="relu")(mainModel)
mainModel = Dropout(0.5)(mainModel)
mainModel = Dense(2, activation="softmax")(mainModel)

#lace the head FC model on top of the base model (actual model)
model = Model(inputs=baseModel.input, outputs=mainModel)

"""looping over all layers in the base model and freeze them so they will 
   not be updated during the first training process"""
for layer in baseModel.layers:
    layer.trainable = False
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet101v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 171319296/171317808 [==============================] - 6s 0us/step

# %%
model.summary()
# Out:
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 230, 230, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1_conv (Conv2D)             (None, 112, 112, 64) 9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# pool1_pad (ZeroPadding2D)       (None, 114, 114, 64) 0           conv1_conv[0][0]
# __________________________________________________________________________________________________
# pool1_pool (MaxPooling2D)       (None, 56, 56, 64)   0           pool1_pad[0][0]
# __________________________________________________________________________________________________
# conv2_block1_preact_bn (BatchNo (None, 56, 56, 64)   256         pool1_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_preact_relu (Activ (None, 56, 56, 64)   0           conv2_block1_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_conv (Conv2D)    (None, 56, 56, 64)   4096        conv2_block1_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_relu (Activation (None, 56, 56, 64)   0           conv2_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_pad (ZeroPadding (None, 58, 58, 64)   0           conv2_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_conv (Conv2D)    (None, 56, 56, 64)   36864       conv2_block1_2_pad[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_relu (Activation (None, 56, 56, 64)   0           conv2_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_conv (Conv2D)    (None, 56, 56, 256)  16640       conv2_block1_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_3_conv (Conv2D)    (None, 56, 56, 256)  16640       conv2_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_out (Add)          (None, 56, 56, 256)  0           conv2_block1_0_conv[0][0]
#                                                                  conv2_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_preact_bn (BatchNo (None, 56, 56, 256)  1024        conv2_block1_out[0][0]
# __________________________________________________________________________________________________
# conv2_block2_preact_relu (Activ (None, 56, 56, 256)  0           conv2_block2_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_conv (Conv2D)    (None, 56, 56, 64)   16384       conv2_block2_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_relu (Activation (None, 56, 56, 64)   0           conv2_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_pad (ZeroPadding (None, 58, 58, 64)   0           conv2_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_conv (Conv2D)    (None, 56, 56, 64)   36864       conv2_block2_2_pad[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_relu (Activation (None, 56, 56, 64)   0           conv2_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_3_conv (Conv2D)    (None, 56, 56, 256)  16640       conv2_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_out (Add)          (None, 56, 56, 256)  0           conv2_block1_out[0][0]
#                                                                  conv2_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_preact_bn (BatchNo (None, 56, 56, 256)  1024        conv2_block2_out[0][0]
# __________________________________________________________________________________________________
# conv2_block3_preact_relu (Activ (None, 56, 56, 256)  0           conv2_block3_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_conv (Conv2D)    (None, 56, 56, 64)   16384       conv2_block3_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_relu (Activation (None, 56, 56, 64)   0           conv2_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_pad (ZeroPadding (None, 58, 58, 64)   0           conv2_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_conv (Conv2D)    (None, 28, 28, 64)   36864       conv2_block3_2_pad[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_bn (BatchNormali (None, 28, 28, 64)   256         conv2_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_relu (Activation (None, 28, 28, 64)   0           conv2_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 28, 28, 256)  0           conv2_block2_out[0][0]
# __________________________________________________________________________________________________
# conv2_block3_3_conv (Conv2D)    (None, 28, 28, 256)  16640       conv2_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_out (Add)          (None, 28, 28, 256)  0           max_pooling2d[0][0]
#                                                                  conv2_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_preact_bn (BatchNo (None, 28, 28, 256)  1024        conv2_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block1_preact_relu (Activ (None, 28, 28, 256)  0           conv3_block1_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_conv (Conv2D)    (None, 28, 28, 128)  32768       conv3_block1_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_relu (Activation (None, 28, 28, 128)  0           conv3_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_pad (ZeroPadding (None, 30, 30, 128)  0           conv3_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_conv (Conv2D)    (None, 28, 28, 128)  147456      conv3_block1_2_pad[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_relu (Activation (None, 28, 28, 128)  0           conv3_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_conv (Conv2D)    (None, 28, 28, 512)  131584      conv3_block1_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_3_conv (Conv2D)    (None, 28, 28, 512)  66048       conv3_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_out (Add)          (None, 28, 28, 512)  0           conv3_block1_0_conv[0][0]
#                                                                  conv3_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_preact_bn (BatchNo (None, 28, 28, 512)  2048        conv3_block1_out[0][0]
# __________________________________________________________________________________________________
# conv3_block2_preact_relu (Activ (None, 28, 28, 512)  0           conv3_block2_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_conv (Conv2D)    (None, 28, 28, 128)  65536       conv3_block2_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_relu (Activation (None, 28, 28, 128)  0           conv3_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_pad (ZeroPadding (None, 30, 30, 128)  0           conv3_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_conv (Conv2D)    (None, 28, 28, 128)  147456      conv3_block2_2_pad[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_relu (Activation (None, 28, 28, 128)  0           conv3_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_3_conv (Conv2D)    (None, 28, 28, 512)  66048       conv3_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_out (Add)          (None, 28, 28, 512)  0           conv3_block1_out[0][0]
#                                                                  conv3_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_preact_bn (BatchNo (None, 28, 28, 512)  2048        conv3_block2_out[0][0]
# __________________________________________________________________________________________________
# conv3_block3_preact_relu (Activ (None, 28, 28, 512)  0           conv3_block3_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_conv (Conv2D)    (None, 28, 28, 128)  65536       conv3_block3_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_relu (Activation (None, 28, 28, 128)  0           conv3_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_pad (ZeroPadding (None, 30, 30, 128)  0           conv3_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_conv (Conv2D)    (None, 28, 28, 128)  147456      conv3_block3_2_pad[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_relu (Activation (None, 28, 28, 128)  0           conv3_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_3_conv (Conv2D)    (None, 28, 28, 512)  66048       conv3_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_out (Add)          (None, 28, 28, 512)  0           conv3_block2_out[0][0]
#                                                                  conv3_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_preact_bn (BatchNo (None, 28, 28, 512)  2048        conv3_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block4_preact_relu (Activ (None, 28, 28, 512)  0           conv3_block4_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_conv (Conv2D)    (None, 28, 28, 128)  65536       conv3_block4_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_relu (Activation (None, 28, 28, 128)  0           conv3_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_pad (ZeroPadding (None, 30, 30, 128)  0           conv3_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_conv (Conv2D)    (None, 14, 14, 128)  147456      conv3_block4_2_pad[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_bn (BatchNormali (None, 14, 14, 128)  512         conv3_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_relu (Activation (None, 14, 14, 128)  0           conv3_block4_2_bn[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 14, 14, 512)  0           conv3_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block4_3_conv (Conv2D)    (None, 14, 14, 512)  66048       conv3_block4_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_out (Add)          (None, 14, 14, 512)  0           max_pooling2d_1[0][0]
#                                                                  conv3_block4_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_preact_bn (BatchNo (None, 14, 14, 512)  2048        conv3_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block1_preact_relu (Activ (None, 14, 14, 512)  0           conv4_block1_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_conv (Conv2D)    (None, 14, 14, 256)  131072      conv4_block1_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_relu (Activation (None, 14, 14, 256)  0           conv4_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_pad (ZeroPadding (None, 16, 16, 256)  0           conv4_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_conv (Conv2D)    (None, 14, 14, 256)  589824      conv4_block1_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_relu (Activation (None, 14, 14, 256)  0           conv4_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_conv (Conv2D)    (None, 14, 14, 1024) 525312      conv4_block1_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_out (Add)          (None, 14, 14, 1024) 0           conv4_block1_0_conv[0][0]
#                                                                  conv4_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_preact_bn (BatchNo (None, 14, 14, 1024) 4096        conv4_block1_out[0][0]
# __________________________________________________________________________________________________
# conv4_block2_preact_relu (Activ (None, 14, 14, 1024) 0           conv4_block2_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_conv (Conv2D)    (None, 14, 14, 256)  262144      conv4_block2_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_relu (Activation (None, 14, 14, 256)  0           conv4_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_pad (ZeroPadding (None, 16, 16, 256)  0           conv4_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_conv (Conv2D)    (None, 14, 14, 256)  589824      conv4_block2_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_relu (Activation (None, 14, 14, 256)  0           conv4_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_out (Add)          (None, 14, 14, 1024) 0           conv4_block1_out[0][0]
#                                                                  conv4_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_preact_bn (BatchNo (None, 14, 14, 1024) 4096        conv4_block2_out[0][0]
# __________________________________________________________________________________________________
# conv4_block3_preact_relu (Activ (None, 14, 14, 1024) 0           conv4_block3_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_conv (Conv2D)    (None, 14, 14, 256)  262144      conv4_block3_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_relu (Activation (None, 14, 14, 256)  0           conv4_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_pad (ZeroPadding (None, 16, 16, 256)  0           conv4_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_conv (Conv2D)    (None, 14, 14, 256)  589824      conv4_block3_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_relu (Activation (None, 14, 14, 256)  0           conv4_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_out (Add)          (None, 14, 14, 1024) 0           conv4_block2_out[0][0]
#                                                                  conv4_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_preact_bn (BatchNo (None, 14, 14, 1024) 4096        conv4_block3_out[0][0]
# __________________________________________________________________________________________________
# conv4_block4_preact_relu (Activ (None, 14, 14, 1024) 0           conv4_block4_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_conv (Conv2D)    (None, 14, 14, 256)  262144      conv4_block4_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_relu (Activation (None, 14, 14, 256)  0           conv4_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_pad (ZeroPadding (None, 16, 16, 256)  0           conv4_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_conv (Conv2D)    (None, 14, 14, 256)  589824      conv4_block4_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_relu (Activation (None, 14, 14, 256)  0           conv4_block4_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block4_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_out (Add)          (None, 14, 14, 1024) 0           conv4_block3_out[0][0]
#                                                                  conv4_block4_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_preact_bn (BatchNo (None, 14, 14, 1024) 4096        conv4_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block5_preact_relu (Activ (None, 14, 14, 1024) 0           conv4_block5_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_conv (Conv2D)    (None, 14, 14, 256)  262144      conv4_block5_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block5_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_relu (Activation (None, 14, 14, 256)  0           conv4_block5_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_pad (ZeroPadding (None, 16, 16, 256)  0           conv4_block5_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_conv (Conv2D)    (None, 14, 14, 256)  589824      conv4_block5_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block5_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_relu (Activation (None, 14, 14, 256)  0           conv4_block5_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block5_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_out (Add)          (None, 14, 14, 1024) 0           conv4_block4_out[0][0]
#                                                                  conv4_block5_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_preact_bn (BatchNo (None, 14, 14, 1024) 4096        conv4_block5_out[0][0]
# __________________________________________________________________________________________________
# conv4_block6_preact_relu (Activ (None, 14, 14, 1024) 0           conv4_block6_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_conv (Conv2D)    (None, 14, 14, 256)  262144      conv4_block6_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block6_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_relu (Activation (None, 14, 14, 256)  0           conv4_block6_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_pad (ZeroPadding (None, 16, 16, 256)  0           conv4_block6_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_conv (Conv2D)    (None, 14, 14, 256)  589824      conv4_block6_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block6_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_relu (Activation (None, 14, 14, 256)  0           conv4_block6_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block6_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_out (Add)          (None, 14, 14, 1024) 0           conv4_block5_out[0][0]
#                                                                  conv4_block6_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block7_preact_bn (BatchNo (None, 14, 14, 1024) 4096        conv4_block6_out[0][0]
# __________________________________________________________________________________________________
# conv4_block7_preact_relu (Activ (None, 14, 14, 1024) 0           conv4_block7_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block7_1_conv (Conv2D)    (None, 14, 14, 256)  262144      conv4_block7_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block7_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block7_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block7_1_relu (Activation (None, 14, 14, 256)  0           conv4_block7_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block7_2_pad (ZeroPadding (None, 16, 16, 256)  0           conv4_block7_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block7_2_conv (Conv2D)    (None, 14, 14, 256)  589824      conv4_block7_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block7_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block7_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block7_2_relu (Activation (None, 14, 14, 256)  0           conv4_block7_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block7_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block7_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block7_out (Add)          (None, 14, 14, 1024) 0           conv4_block6_out[0][0]
#                                                                  conv4_block7_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block8_preact_bn (BatchNo (None, 14, 14, 1024) 4096        conv4_block7_out[0][0]
# __________________________________________________________________________________________________
# conv4_block8_preact_relu (Activ (None, 14, 14, 1024) 0           conv4_block8_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block8_1_conv (Conv2D)    (None, 14, 14, 256)  262144      conv4_block8_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block8_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block8_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block8_1_relu (Activation (None, 14, 14, 256)  0           conv4_block8_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block8_2_pad (ZeroPadding (None, 16, 16, 256)  0           conv4_block8_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block8_2_conv (Conv2D)    (None, 14, 14, 256)  589824      conv4_block8_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block8_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block8_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block8_2_relu (Activation (None, 14, 14, 256)  0           conv4_block8_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block8_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block8_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block8_out (Add)          (None, 14, 14, 1024) 0           conv4_block7_out[0][0]
#                                                                  conv4_block8_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block9_preact_bn (BatchNo (None, 14, 14, 1024) 4096        conv4_block8_out[0][0]
# __________________________________________________________________________________________________
# conv4_block9_preact_relu (Activ (None, 14, 14, 1024) 0           conv4_block9_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block9_1_conv (Conv2D)    (None, 14, 14, 256)  262144      conv4_block9_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block9_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block9_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block9_1_relu (Activation (None, 14, 14, 256)  0           conv4_block9_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block9_2_pad (ZeroPadding (None, 16, 16, 256)  0           conv4_block9_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block9_2_conv (Conv2D)    (None, 14, 14, 256)  589824      conv4_block9_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block9_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block9_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block9_2_relu (Activation (None, 14, 14, 256)  0           conv4_block9_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block9_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block9_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block9_out (Add)          (None, 14, 14, 1024) 0           conv4_block8_out[0][0]
#                                                                  conv4_block9_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block10_preact_bn (BatchN (None, 14, 14, 1024) 4096        conv4_block9_out[0][0]
# __________________________________________________________________________________________________
# conv4_block10_preact_relu (Acti (None, 14, 14, 1024) 0           conv4_block10_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block10_1_conv (Conv2D)   (None, 14, 14, 256)  262144      conv4_block10_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block10_1_bn (BatchNormal (None, 14, 14, 256)  1024        conv4_block10_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block10_1_relu (Activatio (None, 14, 14, 256)  0           conv4_block10_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block10_2_pad (ZeroPaddin (None, 16, 16, 256)  0           conv4_block10_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block10_2_conv (Conv2D)   (None, 14, 14, 256)  589824      conv4_block10_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block10_2_bn (BatchNormal (None, 14, 14, 256)  1024        conv4_block10_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block10_2_relu (Activatio (None, 14, 14, 256)  0           conv4_block10_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block10_3_conv (Conv2D)   (None, 14, 14, 1024) 263168      conv4_block10_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block10_out (Add)         (None, 14, 14, 1024) 0           conv4_block9_out[0][0]
#                                                                  conv4_block10_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block11_preact_bn (BatchN (None, 14, 14, 1024) 4096        conv4_block10_out[0][0]
# __________________________________________________________________________________________________
# conv4_block11_preact_relu (Acti (None, 14, 14, 1024) 0           conv4_block11_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block11_1_conv (Conv2D)   (None, 14, 14, 256)  262144      conv4_block11_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block11_1_bn (BatchNormal (None, 14, 14, 256)  1024        conv4_block11_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block11_1_relu (Activatio (None, 14, 14, 256)  0           conv4_block11_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block11_2_pad (ZeroPaddin (None, 16, 16, 256)  0           conv4_block11_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block11_2_conv (Conv2D)   (None, 14, 14, 256)  589824      conv4_block11_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block11_2_bn (BatchNormal (None, 14, 14, 256)  1024        conv4_block11_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block11_2_relu (Activatio (None, 14, 14, 256)  0           conv4_block11_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block11_3_conv (Conv2D)   (None, 14, 14, 1024) 263168      conv4_block11_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block11_out (Add)         (None, 14, 14, 1024) 0           conv4_block10_out[0][0]
#                                                                  conv4_block11_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block12_preact_bn (BatchN (None, 14, 14, 1024) 4096        conv4_block11_out[0][0]
# __________________________________________________________________________________________________
# conv4_block12_preact_relu (Acti (None, 14, 14, 1024) 0           conv4_block12_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block12_1_conv (Conv2D)   (None, 14, 14, 256)  262144      conv4_block12_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block12_1_bn (BatchNormal (None, 14, 14, 256)  1024        conv4_block12_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block12_1_relu (Activatio (None, 14, 14, 256)  0           conv4_block12_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block12_2_pad (ZeroPaddin (None, 16, 16, 256)  0           conv4_block12_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block12_2_conv (Conv2D)   (None, 14, 14, 256)  589824      conv4_block12_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block12_2_bn (BatchNormal (None, 14, 14, 256)  1024        conv4_block12_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block12_2_relu (Activatio (None, 14, 14, 256)  0           conv4_block12_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block12_3_conv (Conv2D)   (None, 14, 14, 1024) 263168      conv4_block12_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block12_out (Add)         (None, 14, 14, 1024) 0           conv4_block11_out[0][0]
#                                                                  conv4_block12_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block13_preact_bn (BatchN (None, 14, 14, 1024) 4096        conv4_block12_out[0][0]
# __________________________________________________________________________________________________
# conv4_block13_preact_relu (Acti (None, 14, 14, 1024) 0           conv4_block13_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block13_1_conv (Conv2D)   (None, 14, 14, 256)  262144      conv4_block13_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block13_1_bn (BatchNormal (None, 14, 14, 256)  1024        conv4_block13_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block13_1_relu (Activatio (None, 14, 14, 256)  0           conv4_block13_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block13_2_pad (ZeroPaddin (None, 16, 16, 256)  0           conv4_block13_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block13_2_conv (Conv2D)   (None, 14, 14, 256)  589824      conv4_block13_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block13_2_bn (BatchNormal (None, 14, 14, 256)  1024        conv4_block13_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block13_2_relu (Activatio (None, 14, 14, 256)  0           conv4_block13_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block13_3_conv (Conv2D)   (None, 14, 14, 1024) 263168      conv4_block13_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block13_out (Add)         (None, 14, 14, 1024) 0           conv4_block12_out[0][0]
#                                                                  conv4_block13_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block14_preact_bn (BatchN (None, 14, 14, 1024) 4096        conv4_block13_out[0][0]
# ...
# conv4_block20_out (Add)         (None, 14, 14, 1024) 0           conv4_block19_out[0][0]
#                                                                  conv4_block20_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block21_preact_bn (BatchN (None, 14, 14, 1024) 4096        conv4_block20_out[0][0]
# __________________________________________________________________________________________________
# conv4_block21_preact_relu (Acti (None, 14, 14, 1024) 0           conv4_block21_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block21_1_conv (Conv2D)   (None, 14, 14, 256)  262144      conv4_block21_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block21_1_bn (BatchNormal (None, 14, 14, 256)  1024        conv4_block21_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block21_1_relu (Activatio (None, 14, 14, 256)  0           conv4_block21_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block21_2_pad (ZeroPaddin (None, 16, 16, 256)  0           conv4_block21_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block21_2_conv (Conv2D)   (None, 14, 14, 256)  589824      conv4_block21_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block21_2_bn (BatchNormal (None, 14, 14, 256)  1024        conv4_block21_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block21_2_relu (Activatio (None, 14, 14, 256)  0           conv4_block21_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block21_3_conv (Conv2D)   (None, 14, 14, 1024) 263168      conv4_block21_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block21_out (Add)         (None, 14, 14, 1024) 0           conv4_block20_out[0][0]
#                                                                  conv4_block21_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block22_preact_bn (BatchN (None, 14, 14, 1024) 4096        conv4_block21_out[0][0]
# __________________________________________________________________________________________________
# conv4_block22_preact_relu (Acti (None, 14, 14, 1024) 0           conv4_block22_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block22_1_conv (Conv2D)   (None, 14, 14, 256)  262144      conv4_block22_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block22_1_bn (BatchNormal (None, 14, 14, 256)  1024        conv4_block22_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block22_1_relu (Activatio (None, 14, 14, 256)  0           conv4_block22_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block22_2_pad (ZeroPaddin (None, 16, 16, 256)  0           conv4_block22_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block22_2_conv (Conv2D)   (None, 14, 14, 256)  589824      conv4_block22_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block22_2_bn (BatchNormal (None, 14, 14, 256)  1024        conv4_block22_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block22_2_relu (Activatio (None, 14, 14, 256)  0           conv4_block22_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block22_3_conv (Conv2D)   (None, 14, 14, 1024) 263168      conv4_block22_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block22_out (Add)         (None, 14, 14, 1024) 0           conv4_block21_out[0][0]
#                                                                  conv4_block22_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block23_preact_bn (BatchN (None, 14, 14, 1024) 4096        conv4_block22_out[0][0]
# __________________________________________________________________________________________________
# conv4_block23_preact_relu (Acti (None, 14, 14, 1024) 0           conv4_block23_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block23_1_conv (Conv2D)   (None, 14, 14, 256)  262144      conv4_block23_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block23_1_bn (BatchNormal (None, 14, 14, 256)  1024        conv4_block23_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block23_1_relu (Activatio (None, 14, 14, 256)  0           conv4_block23_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block23_2_pad (ZeroPaddin (None, 16, 16, 256)  0           conv4_block23_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block23_2_conv (Conv2D)   (None, 7, 7, 256)    589824      conv4_block23_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block23_2_bn (BatchNormal (None, 7, 7, 256)    1024        conv4_block23_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block23_2_relu (Activatio (None, 7, 7, 256)    0           conv4_block23_2_bn[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 7, 7, 1024)   0           conv4_block22_out[0][0]
# __________________________________________________________________________________________________
# conv4_block23_3_conv (Conv2D)   (None, 7, 7, 1024)   263168      conv4_block23_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block23_out (Add)         (None, 7, 7, 1024)   0           max_pooling2d_2[0][0]
#                                                                  conv4_block23_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_preact_bn (BatchNo (None, 7, 7, 1024)   4096        conv4_block23_out[0][0]
# __________________________________________________________________________________________________
# conv5_block1_preact_relu (Activ (None, 7, 7, 1024)   0           conv5_block1_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_conv (Conv2D)    (None, 7, 7, 512)    524288      conv5_block1_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_relu (Activation (None, 7, 7, 512)    0           conv5_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_pad (ZeroPadding (None, 9, 9, 512)    0           conv5_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_conv (Conv2D)    (None, 7, 7, 512)    2359296     conv5_block1_2_pad[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_relu (Activation (None, 7, 7, 512)    0           conv5_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_0_conv (Conv2D)    (None, 7, 7, 2048)   2099200     conv5_block1_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_3_conv (Conv2D)    (None, 7, 7, 2048)   1050624     conv5_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_out (Add)          (None, 7, 7, 2048)   0           conv5_block1_0_conv[0][0]
#                                                                  conv5_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_preact_bn (BatchNo (None, 7, 7, 2048)   8192        conv5_block1_out[0][0]
# __________________________________________________________________________________________________
# conv5_block2_preact_relu (Activ (None, 7, 7, 2048)   0           conv5_block2_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_conv (Conv2D)    (None, 7, 7, 512)    1048576     conv5_block2_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_relu (Activation (None, 7, 7, 512)    0           conv5_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_pad (ZeroPadding (None, 9, 9, 512)    0           conv5_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_conv (Conv2D)    (None, 7, 7, 512)    2359296     conv5_block2_2_pad[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_relu (Activation (None, 7, 7, 512)    0           conv5_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_3_conv (Conv2D)    (None, 7, 7, 2048)   1050624     conv5_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_out (Add)          (None, 7, 7, 2048)   0           conv5_block1_out[0][0]
#                                                                  conv5_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_preact_bn (BatchNo (None, 7, 7, 2048)   8192        conv5_block2_out[0][0]
# __________________________________________________________________________________________________
# conv5_block3_preact_relu (Activ (None, 7, 7, 2048)   0           conv5_block3_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_conv (Conv2D)    (None, 7, 7, 512)    1048576     conv5_block3_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_relu (Activation (None, 7, 7, 512)    0           conv5_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_pad (ZeroPadding (None, 9, 9, 512)    0           conv5_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_conv (Conv2D)    (None, 7, 7, 512)    2359296     conv5_block3_2_pad[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_relu (Activation (None, 7, 7, 512)    0           conv5_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_3_conv (Conv2D)    (None, 7, 7, 2048)   1050624     conv5_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_out (Add)          (None, 7, 7, 2048)   0           conv5_block2_out[0][0]
#                                                                  conv5_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# post_bn (BatchNormalization)    (None, 7, 7, 2048)   8192        conv5_block3_out[0][0]
# __________________________________________________________________________________________________
# post_relu (Activation)          (None, 7, 7, 2048)   0           post_bn[0][0]
# __________________________________________________________________________________________________
# average_pooling2d (AveragePooli (None, 1, 1, 2048)   0           post_relu[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 2048)         0           average_pooling2d[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 64)           131136      flatten[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 64)           0           dense[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 2)            130         dropout[0][0]
# ==================================================================================================
# Total params: 42,757,826
# Trainable params: 131,266
# Non-trainable params: 42,626,560
# __________________________________________________________________________________________________

# %%
import keras
import tensorflow as tf

# %%
tf.keras.utils.plot_model(model, 'Wazir_first_model.png')
# Out:
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.898637 to fit

# %%
#compiling up the model
optimizer = Adam(lr=learningRate, decay=learningRate / epochs)
model.compile(loss="binary_crossentropy", optimizer=optimizer, metrics=["accuracy"])

#training the head of the network
networkHead = model.fit_generator(
    trainAug.flow(trainX, trainY, batch_size=batchSize),
    steps_per_epoch=len(trainX) // batchSize,
    validation_data=(testX, testY),
    validation_steps=len(testX) // batchSize,
    epochs=epochs)
# Out:
# WARNING:tensorflow:From <ipython-input-12-8a3fdb72e70e>:11: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# Epoch 1/500
# 11/11 [==============================] - 5s 481ms/step - loss: 0.7184 - accuracy: 0.6463 - val_loss: 0.3023 - val_accuracy: 0.8261
# Epoch 2/500
# 11/11 [==============================] - 2s 157ms/step - loss: 0.5776 - accuracy: 0.7561 - val_loss: 0.2312 - val_accuracy: 0.8696
# Epoch 3/500
# 11/11 [==============================] - 2s 151ms/step - loss: 0.3458 - accuracy: 0.8537 - val_loss: 0.2025 - val_accuracy: 0.9565
# Epoch 4/500
# 11/11 [==============================] - 2s 147ms/step - loss: 0.1965 - accuracy: 0.9146 - val_loss: 0.1484 - val_accuracy: 0.9565
# Epoch 5/500
# 11/11 [==============================] - 2s 151ms/step - loss: 0.2496 - accuracy: 0.9146 - val_loss: 0.1270 - val_accuracy: 0.9565
# Epoch 6/500
# 11/11 [==============================] - 2s 150ms/step - loss: 0.1392 - accuracy: 0.9512 - val_loss: 0.1178 - val_accuracy: 0.9565
# Epoch 7/500
# 11/11 [==============================] - 2s 149ms/step - loss: 0.2286 - accuracy: 0.9268 - val_loss: 0.0783 - val_accuracy: 0.9565
# Epoch 8/500
# 11/11 [==============================] - 2s 151ms/step - loss: 0.2007 - accuracy: 0.9512 - val_loss: 0.0783 - val_accuracy: 1.0000
# Epoch 9/500
# 11/11 [==============================] - 2s 152ms/step - loss: 0.1250 - accuracy: 0.9659 - val_loss: 0.0876 - val_accuracy: 0.9565
# Epoch 10/500
# 11/11 [==============================] - 2s 150ms/step - loss: 0.1552 - accuracy: 0.9634 - val_loss: 0.0915 - val_accuracy: 0.9565
# Epoch 11/500
# 11/11 [==============================] - 2s 158ms/step - loss: 0.1913 - accuracy: 0.9634 - val_loss: 0.0982 - val_accuracy: 0.9565
# Epoch 12/500
# 11/11 [==============================] - 2s 150ms/step - loss: 0.1827 - accuracy: 0.9756 - val_loss: 0.0771 - val_accuracy: 0.9565
# Epoch 13/500
# 11/11 [==============================] - 2s 149ms/step - loss: 0.1894 - accuracy: 0.9512 - val_loss: 0.0700 - val_accuracy: 0.9565
# Epoch 14/500
# 11/11 [==============================] - 2s 146ms/step - loss: 0.0957 - accuracy: 0.9634 - val_loss: 0.0644 - val_accuracy: 0.9565
# Epoch 15/500
# 11/11 [==============================] - 2s 147ms/step - loss: 0.0699 - accuracy: 0.9878 - val_loss: 0.0551 - val_accuracy: 1.0000
# Epoch 16/500
# 11/11 [==============================] - 2s 152ms/step - loss: 0.0944 - accuracy: 0.9773 - val_loss: 0.0675 - val_accuracy: 0.9565
# Epoch 17/500
# 11/11 [==============================] - 2s 150ms/step - loss: 0.0903 - accuracy: 0.9512 - val_loss: 0.0799 - val_accuracy: 0.9565
# Epoch 18/500
# 11/11 [==============================] - 2s 156ms/step - loss: 0.1570 - accuracy: 0.9512 - val_loss: 0.0592 - val_accuracy: 0.9565
# Epoch 19/500
# 11/11 [==============================] - 2s 148ms/step - loss: 0.0909 - accuracy: 0.9634 - val_loss: 0.0696 - val_accuracy: 0.9565
# Epoch 20/500
# 11/11 [==============================] - 2s 156ms/step - loss: 0.0821 - accuracy: 0.9756 - val_loss: 0.0670 - val_accuracy: 0.9565
# Epoch 21/500
# 11/11 [==============================] - 2s 147ms/step - loss: 0.0712 - accuracy: 0.9756 - val_loss: 0.0557 - val_accuracy: 1.0000
# Epoch 22/500
# 11/11 [==============================] - 2s 148ms/step - loss: 0.0762 - accuracy: 0.9756 - val_loss: 0.0507 - val_accuracy: 1.0000
# Epoch 23/500
# 11/11 [==============================] - 2s 148ms/step - loss: 0.0705 - accuracy: 0.9878 - val_loss: 0.0480 - val_accuracy: 0.9565
# Epoch 24/500
# 11/11 [==============================] - 2s 151ms/step - loss: 0.0961 - accuracy: 0.9773 - val_loss: 0.0342 - val_accuracy: 1.0000
# Epoch 25/500
# 11/11 [==============================] - 2s 151ms/step - loss: 0.0502 - accuracy: 0.9773 - val_loss: 0.0352 - val_accuracy: 1.0000
# Epoch 26/500
# 11/11 [==============================] - 2s 147ms/step - loss: 0.0782 - accuracy: 0.9634 - val_loss: 0.0438 - val_accuracy: 1.0000
# Epoch 27/500
# 11/11 [==============================] - 2s 148ms/step - loss: 0.0393 - accuracy: 0.9878 - val_loss: 0.0536 - val_accuracy: 0.9565
# Epoch 28/500
# 11/11 [==============================] - 2s 150ms/step - loss: 0.0981 - accuracy: 0.9512 - val_loss: 0.0407 - val_accuracy: 1.0000
# Epoch 29/500
# 11/11 [==============================] - 2s 149ms/step - loss: 0.0892 - accuracy: 0.9634 - val_loss: 0.0733 - val_accuracy: 0.9565
# Epoch 30/500
# 11/11 [==============================] - 2s 147ms/step - loss: 0.0980 - accuracy: 0.9512 - val_loss: 0.0450 - val_accuracy: 1.0000
# Epoch 31/500
# 11/11 [==============================] - 2s 147ms/step - loss: 0.0639 - accuracy: 0.9756 - val_loss: 0.0570 - val_accuracy: 1.0000
# Epoch 32/500
# 11/11 [==============================] - 2s 147ms/step - loss: 0.1503 - accuracy: 0.9268 - val_loss: 0.0495 - val_accuracy: 1.0000
# Epoch 33/500
# 11/11 [==============================] - 2s 148ms/step - loss: 0.0928 - accuracy: 0.9756 - val_loss: 0.0655 - val_accuracy: 0.9565
# Epoch 34/500
# 11/11 [==============================] - 2s 155ms/step - loss: 0.1367 - accuracy: 0.9390 - val_loss: 0.0639 - val_accuracy: 0.9565
# Epoch 35/500
# 11/11 [==============================] - 2s 146ms/step - loss: 0.1145 - accuracy: 0.9634 - val_loss: 0.0615 - val_accuracy: 0.9565
# Epoch 36/500
# 11/11 [==============================] - 2s 147ms/step - loss: 0.1165 - accuracy: 0.9634 - val_loss: 0.0506 - val_accuracy: 1.0000
# Epoch 37/500
# 11/11 [==============================] - 2s 148ms/step - loss: 0.0507 - accuracy: 0.9878 - val_loss: 0.0388 - val_accuracy: 1.0000
# Epoch 38/500
# 11/11 [==============================] - 2s 151ms/step - loss: 0.1047 - accuracy: 0.9634 - val_loss: 0.0861 - val_accuracy: 0.9565
# Epoch 39/500
# 11/11 [==============================] - 2s 147ms/step - loss: 0.1236 - accuracy: 0.9756 - val_loss: 0.1011 - val_accuracy: 0.9565
# Epoch 40/500
# 11/11 [==============================] - 2s 147ms/step - loss: 0.0819 - accuracy: 0.9756 - val_loss: 0.1361 - val_accuracy: 0.9565
# Epoch 41/500
# 11/11 [==============================] - 2s 147ms/step - loss: 0.1944 - accuracy: 0.9146 - val_loss: 0.0888 - val_accuracy: 0.9565
# Epoch 42/500
# 11/11 [==============================] - 2s 147ms/step - loss: 0.1286 - accuracy: 0.9390 - val_loss: 0.0995 - val_accuracy: 0.9130
# Epoch 43/500
# 11/11 [==============================] - 2s 152ms/step - loss: 0.0778 - accuracy: 0.9545 - val_loss: 0.1093 - val_accuracy: 0.9130
# Epoch 44/500
# 11/11 [==============================] - 2s 146ms/step - loss: 0.0849 - accuracy: 0.9878 - val_loss: 0.0322 - val_accuracy: 1.0000
# Epoch 45/500
# 11/11 [==============================] - 2s 147ms/step - loss: 0.1265 - accuracy: 0.9634 - val_loss: 0.0344 - val_accuracy: 1.0000
# Epoch 46/500
# 11/11 [==============================] - 2s 148ms/step - loss: 0.0780 - accuracy: 0.9756 - val_loss: 0.0306 - val_accuracy: 1.0000
# Epoch 47/500
# 11/11 [==============================] - 2s 147ms/step - loss: 0.0902 - accuracy: 0.9634 - val_loss: 0.0326 - val_accuracy: 1.0000
# Epoch 48/500
# 11/11 [==============================] - 2s 146ms/step - loss: 0.0488 - accuracy: 0.9756 - val_loss: 0.0372 - val_accuracy: 1.0000
# Epoch 49/500
# 11/11 [==============================] - 2s 149ms/step - loss: 0.0534 - accuracy: 0.9756 - val_loss: 0.0466 - val_accuracy: 0.9565
# Epoch 50/500
# 11/11 [==============================] - 2s 157ms/step - loss: 0.0680 - accuracy: 0.9634 - val_loss: 0.0274 - val_accuracy: 1.0000
# Epoch 51/500
# 11/11 [==============================] - 2s 146ms/step - loss: 0.1141 - accuracy: 0.9390 - val_loss: 0.0504 - val_accuracy: 1.0000
# Epoch 52/500
# 11/11 [==============================] - 2s 147ms/step - loss: 0.0589 - accuracy: 0.9878 - val_loss: 0.0420 - val_accuracy: 1.0000
# Epoch 53/500
# 11/11 [==============================] - 2s 148ms/step - loss: 0.0899 - accuracy: 0.9634 - val_loss: 0.0389 - val_accuracy: 1.0000
# Epoch 54/500
# 11/11 [==============================] - 2s 156ms/step - loss: 0.0686 - accuracy: 0.9878 - val_loss: 0.0291 - val_accuracy: 1.0000
# Epoch 55/500
# 11/11 [==============================] - 2s 155ms/step - loss: 0.0401 - accuracy: 0.9878 - val_loss: 0.0267 - val_accuracy: 1.0000
# Epoch 56/500
# 11/11 [==============================] - 2s 151ms/step - loss: 0.0792 - accuracy: 0.9659 - val_loss: 0.0261 - val_accuracy: 1.0000
# Epoch 57/500
# 11/11 [==============================] - 2s 145ms/step - loss: 0.1253 - accuracy: 0.9634 - val_loss: 0.0288 - val_accuracy: 1.0000
# Epoch 58/500
# 11/11 [==============================] - 2s 149ms/step - loss: 0.0665 - accuracy: 0.9756 - val_loss: 0.0301 - val_accuracy: 1.0000
# Epoch 59/500
# 11/11 [==============================] - 2s 152ms/step - loss: 0.0632 - accuracy: 0.9878 - val_loss: 0.0406 - val_accuracy: 0.9565
# Epoch 60/500
# 11/11 [==============================] - 2s 157ms/step - loss: 0.1039 - accuracy: 0.9878 - val_loss: 0.0254 - val_accuracy: 1.0000
# Epoch 61/500
# 11/11 [==============================] - 2s 147ms/step - loss: 0.0734 - accuracy: 0.9634 - val_loss: 0.0261 - val_accuracy: 1.0000
# Epoch 62/500
# 11/11 [==============================] - 2s 148ms/step - loss: 0.0475 - accuracy: 0.9756 - val_loss: 0.0263 - val_accuracy: 1.0000
# Epoch 63/500
# 11/11 [==============================] - 2s 148ms/step - loss: 0.1057 - accuracy: 0.9634 - val_loss: 0.0273 - val_accuracy: 1.0000
# Epoch 64/500
# 11/11 [==============================] - 2s 147ms/step - loss: 0.0714 - accuracy: 0.9756 - val_loss: 0.0322 - val_accuracy: 1.0000
# Epoch 65/500
# 11/11 [==============================] - 2s 147ms/step - loss: 0.0357 - accuracy: 0.9878 - val_loss: 0.0377 - val_accuracy: 1.0000
# Epoch 66/500
# 11/11 [==============================] - 2s 149ms/step - loss: 0.0440 - accuracy: 0.9634 - val_loss: 0.0394 - val_accuracy: 1.0000
# Epoch 67/500
# 11/11 [==============================] - 2s 147ms/step - loss: 0.0467 - accuracy: 0.9878 - val_loss: 0.0405 - val_accuracy: 1.0000
# Epoch 68/500
# 11/11 [==============================] - 2s 146ms/step - loss: 0.0352 - accuracy: 0.9756 - val_loss: 0.0379 - val_accuracy: 1.0000
# Epoch 69/500
# 11/11 [==============================] - 2s 145ms/step - loss: 0.0435 - accuracy: 0.9756 - val_loss: 0.0384 - val_accuracy: 1.0000
# Epoch 70/500
# 11/11 [==============================] - 2s 150ms/step - loss: 0.0458 - accuracy: 0.9886 - val_loss: 0.0360 - val_accuracy: 1.0000
# Epoch 71/500
# 11/11 [==============================] - 2s 148ms/step - loss: 0.0411 - accuracy: 0.9756 - val_loss: 0.0339 - val_accuracy: 1.0000
# Epoch 72/500
# 11/11 [==============================] - 2s 155ms/step - loss: 0.0438 - accuracy: 0.9756 - val_loss: 0.0407 - val_accuracy: 1.0000
# Epoch 73/500
# 11/11 [==============================] - 2s 145ms/step - loss: 0.0510 - accuracy: 0.9878 - val_loss: 0.0544 - val_accuracy: 0.9565
# Epoch 74/500
# 11/11 [==============================] - 2s 144ms/step - loss: 0.0691 - accuracy: 0.9756 - val_loss: 0.0495 - val_accuracy: 0.9565
# Epoch 75/500
# 11/11 [==============================] - 2s 145ms/step - loss: 0.0543 - accuracy: 0.9634 - val_loss: 0.0562 - val_accuracy: 0.9565
# Epoch 76/500
# 11/11 [==============================] - 2s 151ms/step - loss: 0.0530 - accuracy: 0.9634 - val_loss: 0.0603 - val_accuracy: 0.9565
# Epoch 77/500
# 11/11 [==============================] - 2s 145ms/step - loss: 0.0446 - accuracy: 0.9878 - val_loss: 0.0789 - val_accuracy: 0.9565
# Epoch 78/500
# 11/11 [==============================] - 2s 148ms/step - loss: 0.0544 - accuracy: 0.9773 - val_loss: 0.0580 - val_accuracy: 0.9565
# Epoch 79/500
# 11/11 [==============================] - 2s 144ms/step - loss: 0.0685 - accuracy: 0.9756 - val_loss: 0.0251 - val_accuracy: 1.0000
# Epoch 80/500
# 11/11 [==============================] - 2s 146ms/step - loss: 0.1045 - accuracy: 0.9512 - val_loss: 0.0227 - val_accuracy: 1.0000
# Epoch 81/500
# 11/11 [==============================] - 2s 143ms/step - loss: 0.1119 - accuracy: 0.9634 - val_loss: 0.0252 - val_accuracy: 1.0000
# Epoch 82/500
# 11/11 [==============================] - 2s 146ms/step - loss: 0.0794 - accuracy: 0.9634 - val_loss: 0.0243 - val_accuracy: 1.0000
# Epoch 83/500
# 11/11 [==============================] - 2s 145ms/step - loss: 0.0452 - accuracy: 0.9878 - val_loss: 0.0206 - val_accuracy: 1.0000
# Epoch 84/500
# 11/11 [==============================] - 2s 147ms/step - loss: 0.0912 - accuracy: 0.9634 - val_loss: 0.0202 - val_accuracy: 1.0000
# Epoch 85/500
# 11/11 [==============================] - 2s 147ms/step - loss: 0.0403 - accuracy: 0.9878 - val_loss: 0.0282 - val_accuracy: 1.0000
# Epoch 86/500
# 11/11 [==============================] - 2s 148ms/step - loss: 0.1104 - accuracy: 0.9634 - val_loss: 0.0334 - val_accuracy: 1.0000
# Epoch 87/500
# 11/11 [==============================] - 2s 145ms/step - loss: 0.0443 - accuracy: 0.9878 - val_loss: 0.0489 - val_accuracy: 0.9565
# Epoch 88/500
# 11/11 [==============================] - 2s 145ms/step - loss: 0.0529 - accuracy: 0.9756 - val_loss: 0.0447 - val_accuracy: 0.9565
# Epoch 89/500
# 11/11 [==============================] - 2s 154ms/step - loss: 0.0593 - accuracy: 0.9756 - val_loss: 0.0319 - val_accuracy: 1.0000
# Epoch 90/500
# 11/11 [==============================] - 2s 145ms/step - loss: 0.0610 - accuracy: 0.9756 - val_loss: 0.0250 - val_accuracy: 1.0000
# Epoch 91/500
# 11/11 [==============================] - 2s 146ms/step - loss: 0.0611 - accuracy: 0.9634 - val_loss: 0.0267 - val_accuracy: 1.0000
# Epoch 92/500
# 11/11 [==============================] - 2s 147ms/step - loss: 0.1340 - accuracy: 0.9634 - val_loss: 0.0354 - val_accuracy: 1.0000
# Epoch 93/500
# 11/11 [==============================] - 2s 147ms/step - loss: 0.0706 - accuracy: 0.9634 - val_loss: 0.0289 - val_accuracy: 1.0000
# Epoch 94/500
# 11/11 [==============================] - 2s 147ms/step - loss: 0.0399 - accuracy: 0.9756 - val_loss: 0.0279 - val_accuracy: 1.0000
# Epoch 95/500
# 11/11 [==============================] - 2s 154ms/step - loss: 0.0478 - accuracy: 0.9878 - val_loss: 0.0313 - val_accuracy: 1.0000
# Epoch 96/500
# 11/11 [==============================] - 2s 146ms/step - loss: 0.0234 - accuracy: 1.0000 - val_loss: 0.0448 - val_accuracy: 0.9565
# Epoch 97/500
# 11/11 [==============================] - 2s 148ms/step - loss: 0.0449 - accuracy: 0.9756 - val_loss: 0.0688 - val_accuracy: 0.9565
# Epoch 98/500
# 11/11 [==============================] - 2s 147ms/step - loss: 0.0509 - accuracy: 0.9878 - val_loss: 0.0663 - val_accuracy: 0.9565
# Epoch 99/500
# 11/11 [==============================] - 2s 148ms/step - loss: 0.0519 - accuracy: 0.9878 - val_loss: 0.0260 - val_accuracy: 1.0000
# Epoch 100/500
# 11/11 [==============================] - 2s 148ms/step - loss: 0.1046 - accuracy: 0.9634 - val_loss: 0.0163 - val_accuracy: 1.0000
# Epoch 101/500
# 11/11 [==============================] - 2s 146ms/step - loss: 0.0529 - accuracy: 0.9756 - val_loss: 0.0216 - val_accuracy: 1.0000
# Epoch 102/500
# 11/11 [==============================] - 2s 149ms/step - loss: 0.0376 - accuracy: 1.0000 - val_loss: 0.0225 - val_accuracy: 1.0000
# Epoch 103/500
# 11/11 [==============================] - 2s 147ms/step - loss: 0.0544 - accuracy: 0.9756 - val_loss: 0.0117 - val_accuracy: 1.0000
# Epoch 104/500
# 11/11 [==============================] - 2s 146ms/step - loss: 0.0252 - accuracy: 1.0000 - val_loss: 0.0162 - val_accuracy: 1.0000
# Epoch 105/500
# 11/11 [==============================] - 2s 148ms/step - loss: 0.0938 - accuracy: 0.9512 - val_loss: 0.0261 - val_accuracy: 1.0000
# Epoch 106/500
# 11/11 [==============================] - 2s 146ms/step - loss: 0.0693 - accuracy: 0.9634 - val_loss: 0.0281 - val_accuracy: 1.0000
# Epoch 107/500
# 11/11 [==============================] - 2s 147ms/step - loss: 0.0408 - accuracy: 0.9878 - val_loss: 0.0135 - val_accuracy: 1.0000
# Epoch 108/500
# 11/11 [==============================] - 2s 146ms/step - loss: 0.0939 - accuracy: 0.9634 - val_loss: 0.0095 - val_accuracy: 1.0000
# Epoch 109/500
# 11/11 [==============================] - 2s 146ms/step - loss: 0.1070 - accuracy: 0.9634 - val_loss: 0.0098 - val_accuracy: 1.0000
# Epoch 110/500
# 11/11 [==============================] - 2s 147ms/step - loss: 0.0403 - accuracy: 0.9756 - val_loss: 0.0158 - val_accuracy: 1.0000
# Epoch 111/500
# 11/11 [==============================] - 2s 148ms/step - loss: 0.0645 - accuracy: 0.9512 - val_loss: 0.0202 - val_accuracy: 1.0000
# Epoch 112/500
# 11/11 [==============================] - 2s 147ms/step - loss: 0.0685 - accuracy: 0.9634 - val_loss: 0.0161 - val_accuracy: 1.0000
# Epoch 113/500
# 11/11 [==============================] - 2s 147ms/step - loss: 0.0124 - accuracy: 1.0000 - val_loss: 0.0146 - val_accuracy: 1.0000
# Epoch 114/500
# 11/11 [==============================] - 2s 150ms/step - loss: 0.0622 - accuracy: 0.9545 - val_loss: 0.0145 - val_accuracy: 1.0000
# Epoch 115/500
# 11/11 [==============================] - 2s 148ms/step - loss: 0.0456 - accuracy: 0.9756 - val_loss: 0.0135 - val_accuracy: 1.0000
# Epoch 116/500
# 11/11 [==============================] - 2s 148ms/step - loss: 0.0416 - accuracy: 0.9634 - val_loss: 0.0137 - val_accuracy: 1.0000
# Epoch 117/500
# 11/11 [==============================] - 2s 150ms/step - loss: 0.0623 - accuracy: 0.9659 - val_loss: 0.0146 - val_accuracy: 1.0000
# Epoch 118/500
# 11/11 [==============================] - 2s 149ms/step - loss: 0.0442 - accuracy: 0.9756 - val_loss: 0.0143 - val_accuracy: 1.0000
# Epoch 119/500
# 11/11 [==============================] - 2s 156ms/step - loss: 0.0501 - accuracy: 0.9634 - val_loss: 0.0154 - val_accuracy: 1.0000
# Epoch 120/500
# 11/11 [==============================] - 2s 152ms/step - loss: 0.0745 - accuracy: 0.9773 - val_loss: 0.0144 - val_accuracy: 1.0000
# Epoch 121/500
# 11/11 [==============================] - 2s 147ms/step - loss: 0.0398 - accuracy: 0.9756 - val_loss: 0.0153 - val_accuracy: 1.0000
# Epoch 122/500
# 11/11 [==============================] - 2s 143ms/step - loss: 0.0566 - accuracy: 0.9512 - val_loss: 0.0136 - val_accuracy: 1.0000
# Epoch 123/500
# 11/11 [==============================] - 2s 147ms/step - loss: 0.0862 - accuracy: 0.9756 - val_loss: 0.0125 - val_accuracy: 1.0000
# Epoch 124/500
# 11/11 [==============================] - 2s 145ms/step - loss: 0.0547 - accuracy: 0.9634 - val_loss: 0.0145 - val_accuracy: 1.0000
# Epoch 125/500
# 11/11 [==============================] - 2s 149ms/step - loss: 0.0860 - accuracy: 0.9634 - val_loss: 0.0164 - val_accuracy: 1.0000
# Epoch 126/500
# 11/11 [==============================] - 2s 147ms/step - loss: 0.0564 - accuracy: 0.9634 - val_loss: 0.0089 - val_accuracy: 1.0000
# Epoch 127/500
# 11/11 [==============================] - 2s 146ms/step - loss: 0.0655 - accuracy: 0.9756 - val_loss: 0.0101 - val_accuracy: 1.0000
# Epoch 128/500
# 11/11 [==============================] - 2s 146ms/step - loss: 0.0452 - accuracy: 0.9878 - val_loss: 0.0099 - val_accuracy: 1.0000
# Epoch 129/500
# 11/11 [==============================] - 2s 146ms/step - loss: 0.0411 - accuracy: 0.9878 - val_loss: 0.0103 - val_accuracy: 1.0000
# Epoch 130/500
# 11/11 [==============================] - 2s 147ms/step - loss: 0.0345 - accuracy: 0.9878 - val_loss: 0.0091 - val_accuracy: 1.0000
# Epoch 131/500
# 11/11 [==============================] - 2s 155ms/step - loss: 0.0454 - accuracy: 0.9756 - val_loss: 0.0085 - val_accuracy: 1.0000
# Epoch 132/500
# 11/11 [==============================] - 2s 147ms/step - loss: 0.0824 - accuracy: 0.9756 - val_loss: 0.0105 - val_accuracy: 1.0000
# Epoch 133/500
# 11/11 [==============================] - 2s 147ms/step - loss: 0.0379 - accuracy: 0.9878 - val_loss: 0.0104 - val_accuracy: 1.0000
# Epoch 134/500
# 11/11 [==============================] - 2s 154ms/step - loss: 0.0764 - accuracy: 0.9512 - val_loss: 0.0156 - val_accuracy: 1.0000
# Epoch 135/500
# 11/11 [==============================] - 2s 151ms/step - loss: 0.0298 - accuracy: 0.9878 - val_loss: 0.0271 - val_accuracy: 1.0000
# Epoch 136/500
# 11/11 [==============================] - 2s 150ms/step - loss: 0.0735 - accuracy: 0.9634 - val_loss: 0.0324 - val_accuracy: 1.0000
# Epoch 137/500
# 11/11 [==============================] - 2s 149ms/step - loss: 0.0371 - accuracy: 0.9878 - val_loss: 0.0271 - val_accuracy: 1.0000
# Epoch 138/500
# 11/11 [==============================] - 2s 146ms/step - loss: 0.0532 - accuracy: 0.9634 - val_loss: 0.0652 - val_accuracy: 0.9565
# Epoch 139/500
# 11/11 [==============================] - 2s 150ms/step - loss: 0.0747 - accuracy: 0.9634 - val_loss: 0.0276 - val_accuracy: 1.0000
# Epoch 140/500
# 11/11 [==============================] - 2s 147ms/step - loss: 0.0646 - accuracy: 0.9756 - val_loss: 0.0333 - val_accuracy: 1.0000
# Epoch 141/500
# 11/11 [==============================] - 2s 151ms/step - loss: 0.0736 - accuracy: 0.9773 - val_loss: 0.0180 - val_accuracy: 1.0000
# Epoch 142/500
# 11/11 [==============================] - 2s 147ms/step - loss: 0.0835 - accuracy: 0.9634 - val_loss: 0.0267 - val_accuracy: 1.0000
# Epoch 143/500
# 11/11 [==============================] - 2s 148ms/step - loss: 0.0486 - accuracy: 0.9878 - val_loss: 0.0307 - val_accuracy: 1.0000
# Epoch 144/500
# 11/11 [==============================] - 2s 146ms/step - loss: 0.0618 - accuracy: 0.9878 - val_loss: 0.0185 - val_accuracy: 1.0000
# Epoch 145/500
# 11/11 [==============================] - 2s 147ms/step - loss: 0.0472 - accuracy: 0.9756 - val_loss: 0.0163 - val_accuracy: 1.0000
# Epoch 146/500
# 11/11 [==============================] - 2s 147ms/step - loss: 0.0347 - accuracy: 0.9878 - val_loss: 0.0182 - val_accuracy: 1.0000
# Epoch 147/500
# 11/11 [==============================] - 2s 146ms/step - loss: 0.0608 - accuracy: 0.9634 - val_loss: 0.0203 - val_accuracy: 1.0000
# Epoch 148/500
# 11/11 [==============================] - 2s 146ms/step - loss: 0.0403 - accuracy: 0.9756 - val_loss: 0.0381 - val_accuracy: 1.0000
# Epoch 149/500
# 11/11 [==============================] - 2s 146ms/step - loss: 0.1016 - accuracy: 0.9634 - val_loss: 0.0278 - val_accuracy: 1.0000
# Epoch 150/500
# 11/11 [==============================] - 2s 147ms/step - loss: 0.0327 - accuracy: 0.9878 - val_loss: 0.0191 - val_accuracy: 1.0000
# Epoch 151/500
# 11/11 [==============================] - 2s 154ms/step - loss: 0.0890 - accuracy: 0.9512 - val_loss: 0.0180 - val_accuracy: 1.0000
# Epoch 152/500
# 11/11 [==============================] - 2s 147ms/step - loss: 0.0564 - accuracy: 0.9756 - val_loss: 0.0185 - val_accuracy: 1.0000
# Epoch 153/500
# 11/11 [==============================] - 2s 148ms/step - loss: 0.0934 - accuracy: 0.9634 - val_loss: 0.0177 - val_accuracy: 1.0000
# Epoch 154/500
# 11/11 [==============================] - 2s 152ms/step - loss: 0.0428 - accuracy: 0.9773 - val_loss: 0.0164 - val_accuracy: 1.0000
# Epoch 155/500
# 11/11 [==============================] - 2s 147ms/step - loss: 0.0442 - accuracy: 0.9634 - val_loss: 0.0148 - val_accuracy: 1.0000
# Epoch 156/500
# 11/11 [==============================] - 2s 147ms/step - loss: 0.0480 - accuracy: 0.9756 - val_loss: 0.0158 - val_accuracy: 1.0000
# Epoch 157/500
# 11/11 [==============================] - 2s 144ms/step - loss: 0.0497 - accuracy: 0.9512 - val_loss: 0.0253 - val_accuracy: 1.0000
# Epoch 158/500
# 11/11 [==============================] - 2s 146ms/step - loss: 0.0584 - accuracy: 0.9756 - val_loss: 0.0143 - val_accuracy: 1.0000
# Epoch 159/500
# 11/11 [==============================] - 2s 146ms/step - loss: 0.0324 - accuracy: 0.9878 - val_loss: 0.0134 - val_accuracy: 1.0000
# Epoch 160/500
# 11/11 [==============================] - 2s 147ms/step - loss: 0.0558 - accuracy: 0.9634 - val_loss: 0.0130 - val_accuracy: 1.0000
# Epoch 161/500
# 11/11 [==============================] - 2s 147ms/step - loss: 0.0364 - accuracy: 0.9878 - val_loss: 0.0117 - val_accuracy: 1.0000
# Epoch 162/500
# 11/11 [==============================] - 2s 147ms/step - loss: 0.0583 - accuracy: 0.9512 - val_loss: 0.0217 - val_accuracy: 1.0000
# Epoch 163/500
# 11/11 [==============================] - 2s 149ms/step - loss: 0.0386 - accuracy: 0.9878 - val_loss: 0.0568 - val_accuracy: 0.9565
# Epoch 164/500
# 11/11 [==============================] - 2s 147ms/step - loss: 0.0740 - accuracy: 0.9756 - val_loss: 0.0701 - val_accuracy: 0.9565
# Epoch 165/500
# 11/11 [==============================] - 2s 145ms/step - loss: 0.0556 - accuracy: 0.9634 - val_loss: 0.0247 - val_accuracy: 1.0000
# Epoch 166/500
# 11/11 [==============================] - 2s 148ms/step - loss: 0.0630 - accuracy: 0.9512 - val_loss: 0.0191 - val_accuracy: 1.0000
# Epoch 167/500
# 11/11 [==============================] - 2s 148ms/step - loss: 0.0341 - accuracy: 0.9878 - val_loss: 0.0173 - val_accuracy: 1.0000
# Epoch 168/500
# 11/11 [==============================] - 2s 146ms/step - loss: 0.0464 - accuracy: 0.9756 - val_loss: 0.0200 - val_accuracy: 1.0000
# Epoch 169/500
# 11/11 [==============================] - 2s 156ms/step - loss: 0.0400 - accuracy: 0.9756 - val_loss: 0.0239 - val_accuracy: 1.0000
# Epoch 170/500
# 11/11 [==============================] - 2s 147ms/step - loss: 0.0472 - accuracy: 0.9756 - val_loss: 0.0210 - val_accuracy: 1.0000
# Epoch 171/500
# 11/11 [==============================] - 2s 147ms/step - loss: 0.0652 - accuracy: 0.9634 - val_loss: 0.0181 - val_accuracy: 1.0000
# Epoch 172/500
# 11/11 [==============================] - 2s 145ms/step - loss: 0.0618 - accuracy: 0.9390 - val_loss: 0.0186 - val_accuracy: 1.0000
# Epoch 173/500
# 11/11 [==============================] - 2s 153ms/step - loss: 0.0584 - accuracy: 0.9756 - val_loss: 0.0200 - val_accuracy: 1.0000
# Epoch 174/500
# 11/11 [==============================] - 2s 146ms/step - loss: 0.0315 - accuracy: 1.0000 - val_loss: 0.0158 - val_accuracy: 1.0000
# Epoch 175/500
# 11/11 [==============================] - 2s 147ms/step - loss: 0.0312 - accuracy: 1.0000 - val_loss: 0.0224 - val_accuracy: 1.0000
# Epoch 176/500
# 11/11 [==============================] - 2s 155ms/step - loss: 0.0771 - accuracy: 0.9756 - val_loss: 0.0492 - val_accuracy: 0.9565
# Epoch 177/500
# 11/11 [==============================] - 2s 148ms/step - loss: 0.0537 - accuracy: 0.9634 - val_loss: 0.0448 - val_accuracy: 0.9565
# Epoch 178/500
# 11/11 [==============================] - 2s 147ms/step - loss: 0.0746 - accuracy: 0.9756 - val_loss: 0.0167 - val_accuracy: 1.0000
# Epoch 179/500
# 11/11 [==============================] - 2s 148ms/step - loss: 0.0235 - accuracy: 0.9756 - val_loss: 0.0172 - val_accuracy: 1.0000
# Epoch 180/500
# 11/11 [==============================] - 2s 148ms/step - loss: 0.0799 - accuracy: 0.9634 - val_loss: 0.0188 - val_accuracy: 1.0000
# Epoch 181/500
# 11/11 [==============================] - 2s 149ms/step - loss: 0.0385 - accuracy: 0.9756 - val_loss: 0.0185 - val_accuracy: 1.0000
# Epoch 182/500
# 11/11 [==============================] - 2s 147ms/step - loss: 0.0439 - accuracy: 0.9756 - val_loss: 0.0178 - val_accuracy: 1.0000
# Epoch 183/500
# 11/11 [==============================] - 2s 146ms/step - loss: 0.0361 - accuracy: 0.9878 - val_loss: 0.0157 - val_accuracy: 1.0000
# Epoch 184/500
# 11/11 [==============================] - 2s 149ms/step - loss: 0.0369 - accuracy: 0.9886 - val_loss: 0.0141 - val_accuracy: 1.0000
# Epoch 185/500
# 11/11 [==============================] - 2s 145ms/step - loss: 0.0454 - accuracy: 0.9756 - val_loss: 0.0131 - val_accuracy: 1.0000
# Epoch 186/500
# 11/11 [==============================] - 2s 146ms/step - loss: 0.1055 - accuracy: 0.9512 - val_loss: 0.0191 - val_accuracy: 1.0000
# Epoch 187/500
# 11/11 [==============================] - 2s 149ms/step - loss: 0.0724 - accuracy: 0.9659 - val_loss: 0.0109 - val_accuracy: 1.0000
# Epoch 188/500
# 11/11 [==============================] - 2s 147ms/step - loss: 0.0187 - accuracy: 0.9878 - val_loss: 0.0130 - val_accuracy: 1.0000
# Epoch 189/500
# 11/11 [==============================] - 2s 148ms/step - loss: 0.0508 - accuracy: 0.9634 - val_loss: 0.0107 - val_accuracy: 1.0000
# Epoch 190/500
# 11/11 [==============================] - 2s 146ms/step - loss: 0.0660 - accuracy: 0.9634 - val_loss: 0.0122 - val_accuracy: 1.0000
# Epoch 191/500
# 11/11 [==============================] - 2s 146ms/step - loss: 0.0573 - accuracy: 0.9756 - val_loss: 0.0180 - val_accuracy: 1.0000
# Epoch 192/500
# 11/11 [==============================] - 2s 148ms/step - loss: 0.0340 - accuracy: 0.9878 - val_loss: 0.0218 - val_accuracy: 1.0000
# Epoch 193/500
# 11/11 [==============================] - 2s 146ms/step - loss: 0.0194 - accuracy: 1.0000 - val_loss: 0.0157 - val_accuracy: 1.0000
# Epoch 194/500
# 11/11 [==============================] - 2s 148ms/step - loss: 0.0670 - accuracy: 0.9756 - val_loss: 0.0123 - val_accuracy: 1.0000
# Epoch 195/500
# 11/11 [==============================] - 2s 145ms/step - loss: 0.0626 - accuracy: 0.9756 - val_loss: 0.0133 - val_accuracy: 1.0000
# Epoch 196/500
# 11/11 [==============================] - 2s 145ms/step - loss: 0.0470 - accuracy: 0.9634 - val_loss: 0.0137 - val_accuracy: 1.0000
# Epoch 197/500
# 11/11 [==============================] - 2s 147ms/step - loss: 0.0549 - accuracy: 0.9756 - val_loss: 0.0248 - val_accuracy: 1.0000
# Epoch 198/500
# 11/11 [==============================] - 2s 148ms/step - loss: 0.0280 - accuracy: 0.9878 - val_loss: 0.0277 - val_accuracy: 1.0000
# Epoch 199/500
# 11/11 [==============================] - 2s 148ms/step - loss: 0.1372 - accuracy: 0.9634 - val_loss: 0.0153 - val_accuracy: 1.0000
# Epoch 200/500
# 11/11 [==============================] - 2s 145ms/step - loss: 0.0298 - accuracy: 0.9878 - val_loss: 0.0153 - val_accuracy: 1.0000
# Epoch 201/500
# 11/11 [==============================] - 2s 148ms/step - loss: 0.0386 - accuracy: 0.9878 - val_loss: 0.0149 - val_accuracy: 1.0000
# Epoch 202/500
# 11/11 [==============================] - 2s 142ms/step - loss: 0.0330 - accuracy: 0.9756 - val_loss: 0.0164 - val_accuracy: 1.0000
# Epoch 203/500
# 11/11 [==============================] - 2s 146ms/step - loss: 0.0645 - accuracy: 0.9512 - val_loss: 0.0156 - val_accuracy: 1.0000
# Epoch 204/500
# 11/11 [==============================] - 2s 142ms/step - loss: 0.1071 - accuracy: 0.9756 - val_loss: 0.0206 - val_accuracy: 1.0000
# Epoch 205/500
# 11/11 [==============================] - 2s 148ms/step - loss: 0.1424 - accuracy: 0.9773 - val_loss: 0.0266 - val_accuracy: 1.0000
# Epoch 206/500
# 11/11 [==============================] - 2s 147ms/step - loss: 0.0412 - accuracy: 0.9756 - val_loss: 0.0254 - val_accuracy: 1.0000
# Epoch 207/500
# 11/11 [==============================] - 2s 149ms/step - loss: 0.0253 - accuracy: 0.9878 - val_loss: 0.0199 - val_accuracy: 1.0000
# Epoch 208/500
# 11/11 [==============================] - 2s 147ms/step - loss: 0.0554 - accuracy: 0.9756 - val_loss: 0.0169 - val_accuracy: 1.0000
# Epoch 209/500
# 11/11 [==============================] - 2s 148ms/step - loss: 0.0821 - accuracy: 0.9634 - val_loss: 0.0200 - val_accuracy: 1.0000
# Epoch 210/500
# 11/11 [==============================] - 2s 145ms/step - loss: 0.0312 - accuracy: 0.9878 - val_loss: 0.0173 - val_accuracy: 1.0000
# Epoch 211/500
# 11/11 [==============================] - 2s 149ms/step - loss: 0.0501 - accuracy: 0.9634 - val_loss: 0.0288 - val_accuracy: 1.0000
# Epoch 212/500
# 11/11 [==============================] - 2s 145ms/step - loss: 0.0440 - accuracy: 0.9756 - val_loss: 0.0513 - val_accuracy: 0.9565
# Epoch 213/500
# 11/11 [==============================] - 2s 147ms/step - loss: 0.1317 - accuracy: 0.9756 - val_loss: 0.0399 - val_accuracy: 0.9565
# Epoch 214/500
# 11/11 [==============================] - 2s 145ms/step - loss: 0.0465 - accuracy: 0.9756 - val_loss: 0.0179 - val_accuracy: 1.0000
# Epoch 215/500
# 11/11 [==============================] - 2s 148ms/step - loss: 0.0231 - accuracy: 0.9878 - val_loss: 0.0192 - val_accuracy: 1.0000
# Epoch 216/500
# 11/11 [==============================] - 2s 148ms/step - loss: 0.0854 - accuracy: 0.9512 - val_loss: 0.0183 - val_accuracy: 1.0000
# Epoch 217/500
# 11/11 [==============================] - 2s 162ms/step - loss: 0.0767 - accuracy: 0.9512 - val_loss: 0.0153 - val_accuracy: 1.0000
# Epoch 218/500
# 11/11 [==============================] - 2s 145ms/step - loss: 0.0388 - accuracy: 0.9878 - val_loss: 0.0140 - val_accuracy: 1.0000
# Epoch 219/500
# 11/11 [==============================] - 2s 149ms/step - loss: 0.0224 - accuracy: 1.0000 - val_loss: 0.0134 - val_accuracy: 1.0000
# Epoch 220/500
# 11/11 [==============================] - 2s 152ms/step - loss: 0.0426 - accuracy: 0.9659 - val_loss: 0.0125 - val_accuracy: 1.0000
# Epoch 221/500
# 11/11 [==============================] - 2s 147ms/step - loss: 0.0392 - accuracy: 0.9878 - val_loss: 0.0119 - val_accuracy: 1.0000
# Epoch 222/500
# 11/11 [==============================] - 2s 151ms/step - loss: 0.0598 - accuracy: 0.9756 - val_loss: 0.0136 - val_accuracy: 1.0000
# Epoch 223/500
# 11/11 [==============================] - 2s 156ms/step - loss: 0.0388 - accuracy: 0.9756 - val_loss: 0.0142 - val_accuracy: 1.0000
# Epoch 224/500
# 11/11 [==============================] - 2s 145ms/step - loss: 0.0402 - accuracy: 0.9878 - val_loss: 0.0146 - val_accuracy: 1.0000
# Epoch 225/500
# 11/11 [==============================] - 2s 146ms/step - loss: 0.0409 - accuracy: 0.9878 - val_loss: 0.0130 - val_accuracy: 1.0000
# Epoch 226/500
# 11/11 [==============================] - 2s 146ms/step - loss: 0.0639 - accuracy: 0.9512 - val_loss: 0.0140 - val_accuracy: 1.0000
# Epoch 227/500
# 11/11 [==============================] - 2s 157ms/step - loss: 0.0342 - accuracy: 0.9878 - val_loss: 0.0120 - val_accuracy: 1.0000
# Epoch 228/500
# 11/11 [==============================] - 2s 145ms/step - loss: 0.0321 - accuracy: 0.9878 - val_loss: 0.0104 - val_accuracy: 1.0000
# Epoch 229/500
# 11/11 [==============================] - 2s 148ms/step - loss: 0.0486 - accuracy: 0.9756 - val_loss: 0.0090 - val_accuracy: 1.0000
# Epoch 230/500
# 11/11 [==============================] - 2s 155ms/step - loss: 0.0355 - accuracy: 0.9756 - val_loss: 0.0082 - val_accuracy: 1.0000
# Epoch 231/500
# 11/11 [==============================] - 2s 148ms/step - loss: 0.0459 - accuracy: 0.9756 - val_loss: 0.0087 - val_accuracy: 1.0000
# Epoch 232/500
# 11/11 [==============================] - 2s 156ms/step - loss: 0.0278 - accuracy: 0.9756 - val_loss: 0.0087 - val_accuracy: 1.0000
# Epoch 233/500
# 11/11 [==============================] - 2s 146ms/step - loss: 0.0390 - accuracy: 0.9634 - val_loss: 0.0077 - val_accuracy: 1.0000
# Epoch 234/500
# 11/11 [==============================] - 2s 148ms/step - loss: 0.0433 - accuracy: 0.9878 - val_loss: 0.0074 - val_accuracy: 1.0000
# Epoch 235/500
# 11/11 [==============================] - 2s 148ms/step - loss: 0.0889 - accuracy: 0.9634 - val_loss: 0.0097 - val_accuracy: 1.0000
# Epoch 236/500
# 11/11 [==============================] - 2s 147ms/step - loss: 0.0318 - accuracy: 0.9878 - val_loss: 0.0126 - val_accuracy: 1.0000
# Epoch 237/500
# 11/11 [==============================] - 2s 147ms/step - loss: 0.0414 - accuracy: 0.9756 - val_loss: 0.0134 - val_accuracy: 1.0000
# Epoch 238/500
# 11/11 [==============================] - 2s 149ms/step - loss: 0.0498 - accuracy: 0.9756 - val_loss: 0.0146 - val_accuracy: 1.0000
# Epoch 239/500
# 11/11 [==============================] - 2s 150ms/step - loss: 0.0720 - accuracy: 0.9659 - val_loss: 0.0174 - val_accuracy: 1.0000
# Epoch 240/500
# 11/11 [==============================] - 2s 145ms/step - loss: 0.0300 - accuracy: 0.9878 - val_loss: 0.0197 - val_accuracy: 1.0000
# Epoch 241/500
# 11/11 [==============================] - 2s 144ms/step - loss: 0.0357 - accuracy: 0.9878 - val_loss: 0.0164 - val_accuracy: 1.0000
# Epoch 242/500
# 11/11 [==============================] - 2s 148ms/step - loss: 0.0843 - accuracy: 0.9634 - val_loss: 0.0155 - val_accuracy: 1.0000
# Epoch 243/500
# 11/11 [==============================] - 2s 150ms/step - loss: 0.0359 - accuracy: 0.9756 - val_loss: 0.0143 - val_accuracy: 1.0000
# Epoch 244/500
# 11/11 [==============================] - 2s 149ms/step - loss: 0.0396 - accuracy: 0.9878 - val_loss: 0.0130 - val_accuracy: 1.0000
# Epoch 245/500
# 11/11 [==============================] - 2s 151ms/step - loss: 0.0629 - accuracy: 0.9634 - val_loss: 0.0138 - val_accuracy: 1.0000
# Epoch 246/500
# 11/11 [==============================] - 2s 148ms/step - loss: 0.0444 - accuracy: 0.9756 - val_loss: 0.0129 - val_accuracy: 1.0000
# Epoch 247/500
# 11/11 [==============================] - 2s 148ms/step - loss: 0.0407 - accuracy: 0.9756 - val_loss: 0.0118 - val_accuracy: 1.0000
# Epoch 248/500
# 11/11 [==============================] - 2s 145ms/step - loss: 0.0429 - accuracy: 0.9878 - val_loss: 0.0110 - val_accuracy: 1.0000
# Epoch 249/500
# 11/11 [==============================] - 2s 146ms/step - loss: 0.0200 - accuracy: 0.9756 - val_loss: 0.0103 - val_accuracy: 1.0000
# Epoch 250/500
# 11/11 [==============================] - 2s 150ms/step - loss: 0.0407 - accuracy: 0.9878 - val_loss: 0.0098 - val_accuracy: 1.0000
# Epoch 251/500
# 11/11 [==============================] - 2s 148ms/step - loss: 0.0367 - accuracy: 0.9756 - val_loss: 0.0130 - val_accuracy: 1.0000
# Epoch 252/500
# 11/11 [==============================] - 2s 148ms/step - loss: 0.0305 - accuracy: 0.9878 - val_loss: 0.0118 - val_accuracy: 1.0000
# Epoch 253/500
# 11/11 [==============================] - 2s 147ms/step - loss: 0.0430 - accuracy: 0.9634 - val_loss: 0.0111 - val_accuracy: 1.0000
# Epoch 254/500
# 11/11 [==============================] - 2s 149ms/step - loss: 0.0397 - accuracy: 0.9756 - val_loss: 0.0110 - val_accuracy: 1.0000
# Epoch 255/500
# 11/11 [==============================] - 2s 148ms/step - loss: 0.0260 - accuracy: 0.9878 - val_loss: 0.0106 - val_accuracy: 1.0000
# Epoch 256/500
# 11/11 [==============================] - 2s 148ms/step - loss: 0.0421 - accuracy: 0.9878 - val_loss: 0.0108 - val_accuracy: 1.0000
# Epoch 257/500
# 11/11 [==============================] - 2s 146ms/step - loss: 0.0472 - accuracy: 0.9634 - val_loss: 0.0131 - val_accuracy: 1.0000
# Epoch 258/500
# 11/11 [==============================] - 2s 144ms/step - loss: 0.0379 - accuracy: 0.9878 - val_loss: 0.0166 - val_accuracy: 1.0000
# Epoch 259/500
# 11/11 [==============================] - 2s 148ms/step - loss: 0.0525 - accuracy: 0.9659 - val_loss: 0.0424 - val_accuracy: 0.9565
# Epoch 260/500
# 11/11 [==============================] - 2s 146ms/step - loss: 0.0500 - accuracy: 0.9756 - val_loss: 0.0285 - val_accuracy: 1.0000
# Epoch 261/500
# 11/11 [==============================] - 2s 147ms/step - loss: 0.0508 - accuracy: 0.9756 - val_loss: 0.0218 - val_accuracy: 1.0000
# Epoch 262/500
# 11/11 [==============================] - 2s 146ms/step - loss: 0.0489 - accuracy: 0.9634 - val_loss: 0.0211 - val_accuracy: 1.0000
# Epoch 263/500
# 11/11 [==============================] - 2s 147ms/step - loss: 0.0414 - accuracy: 0.9756 - val_loss: 0.0214 - val_accuracy: 1.0000
# Epoch 264/500
# 11/11 [==============================] - 2s 147ms/step - loss: 0.0303 - accuracy: 0.9756 - val_loss: 0.0209 - val_accuracy: 1.0000
# Epoch 265/500
# 11/11 [==============================] - 2s 148ms/step - loss: 0.0552 - accuracy: 0.9756 - val_loss: 0.0226 - val_accuracy: 1.0000
# Epoch 266/500
# 11/11 [==============================] - 2s 147ms/step - loss: 0.0436 - accuracy: 0.9756 - val_loss: 0.0247 - val_accuracy: 1.0000
# Epoch 267/500
# 11/11 [==============================] - 2s 149ms/step - loss: 0.0413 - accuracy: 0.9773 - val_loss: 0.0237 - val_accuracy: 1.0000
# Epoch 268/500
# 11/11 [==============================] - 2s 142ms/step - loss: 0.0316 - accuracy: 0.9756 - val_loss: 0.0261 - val_accuracy: 1.0000
# Epoch 269/500
# 11/11 [==============================] - 2s 147ms/step - loss: 0.0459 - accuracy: 0.9878 - val_loss: 0.0173 - val_accuracy: 1.0000
# Epoch 270/500
# 11/11 [==============================] - 2s 147ms/step - loss: 0.0608 - accuracy: 0.9756 - val_loss: 0.0163 - val_accuracy: 1.0000
# Epoch 271/500
# 11/11 [==============================] - 2s 151ms/step - loss: 0.0424 - accuracy: 0.9659 - val_loss: 0.0114 - val_accuracy: 1.0000
# Epoch 272/500
# 11/11 [==============================] - 2s 148ms/step - loss: 0.0305 - accuracy: 0.9878 - val_loss: 0.0107 - val_accuracy: 1.0000
# Epoch 273/500
# 11/11 [==============================] - 2s 148ms/step - loss: 0.0353 - accuracy: 0.9878 - val_loss: 0.0095 - val_accuracy: 1.0000
# Epoch 274/500
# 11/11 [==============================] - 2s 148ms/step - loss: 0.0427 - accuracy: 0.9512 - val_loss: 0.0111 - val_accuracy: 1.0000
# Epoch 275/500
# 11/11 [==============================] - 2s 147ms/step - loss: 0.0464 - accuracy: 0.9756 - val_loss: 0.0144 - val_accuracy: 1.0000
# Epoch 276/500
# 11/11 [==============================] - 2s 148ms/step - loss: 0.0487 - accuracy: 0.9756 - val_loss: 0.0164 - val_accuracy: 1.0000
# Epoch 277/500
# 11/11 [==============================] - 2s 147ms/step - loss: 0.0789 - accuracy: 0.9634 - val_loss: 0.0221 - val_accuracy: 1.0000
# Epoch 278/500
# 11/11 [==============================] - 2s 146ms/step - loss: 0.0515 - accuracy: 0.9634 - val_loss: 0.0173 - val_accuracy: 1.0000
# Epoch 279/500
# 11/11 [==============================] - 2s 148ms/step - loss: 0.0520 - accuracy: 0.9756 - val_loss: 0.0161 - val_accuracy: 1.0000
# Epoch 280/500
# 11/11 [==============================] - 2s 150ms/step - loss: 0.0318 - accuracy: 0.9878 - val_loss: 0.0164 - val_accuracy: 1.0000
# Epoch 281/500
# 11/11 [==============================] - 2s 144ms/step - loss: 0.0681 - accuracy: 0.9756 - val_loss: 0.0183 - val_accuracy: 1.0000
# Epoch 282/500
# 11/11 [==============================] - 2s 148ms/step - loss: 0.0579 - accuracy: 0.9756 - val_loss: 0.0191 - val_accuracy: 1.0000
# Epoch 283/500
# 11/11 [==============================] - 2s 147ms/step - loss: 0.0362 - accuracy: 0.9634 - val_loss: 0.0192 - val_accuracy: 1.0000
# Epoch 284/500
# 11/11 [==============================] - 2s 146ms/step - loss: 0.0534 - accuracy: 0.9634 - val_loss: 0.0163 - val_accuracy: 1.0000
# Epoch 285/500
# 11/11 [==============================] - 2s 149ms/step - loss: 0.0471 - accuracy: 0.9773 - val_loss: 0.0140 - val_accuracy: 1.0000
# Epoch 286/500
# 11/11 [==============================] - 2s 155ms/step - loss: 0.0358 - accuracy: 0.9878 - val_loss: 0.0120 - val_accuracy: 1.0000
# Epoch 287/500
# 11/11 [==============================] - 2s 152ms/step - loss: 0.0399 - accuracy: 0.9773 - val_loss: 0.0116 - val_accuracy: 1.0000
# Epoch 288/500
# 11/11 [==============================] - 2s 150ms/step - loss: 0.0402 - accuracy: 0.9773 - val_loss: 0.0114 - val_accuracy: 1.0000
# Epoch 289/500
# 11/11 [==============================] - 2s 148ms/step - loss: 0.0462 - accuracy: 0.9878 - val_loss: 0.0118 - val_accuracy: 1.0000
# Epoch 290/500
# 11/11 [==============================] - 2s 147ms/step - loss: 0.0368 - accuracy: 0.9878 - val_loss: 0.0130 - val_accuracy: 1.0000
# Epoch 291/500
# 11/11 [==============================] - 2s 147ms/step - loss: 0.0673 - accuracy: 0.9634 - val_loss: 0.0128 - val_accuracy: 1.0000
# Epoch 292/500
# 11/11 [==============================] - 2s 146ms/step - loss: 0.0550 - accuracy: 0.9878 - val_loss: 0.0133 - val_accuracy: 1.0000
# Epoch 293/500
# 11/11 [==============================] - 2s 150ms/step - loss: 0.0396 - accuracy: 0.9886 - val_loss: 0.0096 - val_accuracy: 1.0000
# Epoch 294/500
# 11/11 [==============================] - 2s 148ms/step - loss: 0.0197 - accuracy: 0.9878 - val_loss: 0.0082 - val_accuracy: 1.0000
# Epoch 295/500
# 11/11 [==============================] - 2s 146ms/step - loss: 0.0583 - accuracy: 0.9634 - val_loss: 0.0092 - val_accuracy: 1.0000
# Epoch 296/500
# 11/11 [==============================] - 2s 148ms/step - loss: 0.0313 - accuracy: 0.9756 - val_loss: 0.0107 - val_accuracy: 1.0000
# Epoch 297/500
# 11/11 [==============================] - 2s 151ms/step - loss: 0.0629 - accuracy: 0.9659 - val_loss: 0.0089 - val_accuracy: 1.0000
# Epoch 298/500
# 11/11 [==============================] - 2s 156ms/step - loss: 0.0395 - accuracy: 0.9756 - val_loss: 0.0057 - val_accuracy: 1.0000
# Epoch 299/500
# 11/11 [==============================] - 2s 146ms/step - loss: 0.0316 - accuracy: 0.9878 - val_loss: 0.0044 - val_accuracy: 1.0000
# Epoch 300/500
# 11/11 [==============================] - 2s 148ms/step - loss: 0.0535 - accuracy: 0.9634 - val_loss: 0.0043 - val_accuracy: 1.0000
# Epoch 301/500
# 11/11 [==============================] - 2s 152ms/step - loss: 0.0479 - accuracy: 0.9659 - val_loss: 0.0050 - val_accuracy: 1.0000
# Epoch 302/500
# 11/11 [==============================] - 2s 151ms/step - loss: 0.0419 - accuracy: 0.9756 - val_loss: 0.0064 - val_accuracy: 1.0000
# Epoch 303/500
# 11/11 [==============================] - 2s 154ms/step - loss: 0.0316 - accuracy: 0.9659 - val_loss: 0.0071 - val_accuracy: 1.0000
# Epoch 304/500
# 11/11 [==============================] - 2s 149ms/step - loss: 0.0615 - accuracy: 0.9634 - val_loss: 0.0078 - val_accuracy: 1.0000
# Epoch 305/500
# 11/11 [==============================] - 2s 148ms/step - loss: 0.0397 - accuracy: 0.9756 - val_loss: 0.0064 - val_accuracy: 1.0000
# Epoch 306/500
# 11/11 [==============================] - 2s 147ms/step - loss: 0.0415 - accuracy: 0.9634 - val_loss: 0.0067 - val_accuracy: 1.0000
# Epoch 307/500
# 11/11 [==============================] - 2s 146ms/step - loss: 0.0801 - accuracy: 0.9756 - val_loss: 0.0074 - val_accuracy: 1.0000
# Epoch 308/500
# 11/11 [==============================] - 2s 155ms/step - loss: 0.0523 - accuracy: 0.9512 - val_loss: 0.0087 - val_accuracy: 1.0000
# Epoch 309/500
# 11/11 [==============================] - 2s 147ms/step - loss: 0.0471 - accuracy: 0.9756 - val_loss: 0.0104 - val_accuracy: 1.0000
# Epoch 310/500
# 11/11 [==============================] - 2s 152ms/step - loss: 0.0423 - accuracy: 0.9773 - val_loss: 0.0114 - val_accuracy: 1.0000
# Epoch 311/500
# 11/11 [==============================] - 2s 147ms/step - loss: 0.0487 - accuracy: 0.9756 - val_loss: 0.0110 - val_accuracy: 1.0000
# Epoch 312/500
# 11/11 [==============================] - 2s 148ms/step - loss: 0.0367 - accuracy: 0.9756 - val_loss: 0.0084 - val_accuracy: 1.0000
# Epoch 313/500
# 11/11 [==============================] - 2s 149ms/step - loss: 0.0271 - accuracy: 0.9756 - val_loss: 0.0085 - val_accuracy: 1.0000
# Epoch 314/500
# 11/11 [==============================] - 2s 146ms/step - loss: 0.0506 - accuracy: 0.9878 - val_loss: 0.0074 - val_accuracy: 1.0000
# Epoch 315/500
# 11/11 [==============================] - 2s 146ms/step - loss: 0.0496 - accuracy: 0.9878 - val_loss: 0.0066 - val_accuracy: 1.0000
# Epoch 316/500
# 11/11 [==============================] - 2s 145ms/step - loss: 0.0427 - accuracy: 0.9756 - val_loss: 0.0058 - val_accuracy: 1.0000
# Epoch 317/500
# 11/11 [==============================] - 2s 152ms/step - loss: 0.0385 - accuracy: 0.9773 - val_loss: 0.0058 - val_accuracy: 1.0000
# Epoch 318/500
# 11/11 [==============================] - 2s 147ms/step - loss: 0.0467 - accuracy: 0.9756 - val_loss: 0.0065 - val_accuracy: 1.0000
# Epoch 319/500
# 11/11 [==============================] - 2s 144ms/step - loss: 0.0444 - accuracy: 0.9756 - val_loss: 0.0114 - val_accuracy: 1.0000
# Epoch 320/500
# 11/11 [==============================] - 2s 153ms/step - loss: 0.0355 - accuracy: 0.9756 - val_loss: 0.0234 - val_accuracy: 1.0000
# Epoch 321/500
# 11/11 [==============================] - 2s 146ms/step - loss: 0.0314 - accuracy: 0.9878 - val_loss: 0.0280 - val_accuracy: 1.0000
# Epoch 322/500
# 11/11 [==============================] - 2s 148ms/step - loss: 0.0501 - accuracy: 0.9756 - val_loss: 0.0280 - val_accuracy: 1.0000
# Epoch 323/500
# 11/11 [==============================] - 2s 146ms/step - loss: 0.0264 - accuracy: 1.0000 - val_loss: 0.0302 - val_accuracy: 1.0000
# Epoch 324/500
# 11/11 [==============================] - 2s 146ms/step - loss: 0.0413 - accuracy: 0.9878 - val_loss: 0.0271 - val_accuracy: 1.0000
# Epoch 325/500
# 11/11 [==============================] - 2s 149ms/step - loss: 0.0507 - accuracy: 0.9773 - val_loss: 0.0172 - val_accuracy: 1.0000
# Epoch 326/500
# 11/11 [==============================] - 2s 147ms/step - loss: 0.0632 - accuracy: 0.9512 - val_loss: 0.0056 - val_accuracy: 1.0000
# Epoch 327/500
# 11/11 [==============================] - 2s 147ms/step - loss: 0.0356 - accuracy: 0.9756 - val_loss: 0.0047 - val_accuracy: 1.0000
# Epoch 328/500
# 11/11 [==============================] - 2s 147ms/step - loss: 0.0567 - accuracy: 0.9756 - val_loss: 0.0062 - val_accuracy: 1.0000
# Epoch 329/500
# 11/11 [==============================] - 2s 149ms/step - loss: 0.0451 - accuracy: 0.9634 - val_loss: 0.0067 - val_accuracy: 1.0000
# Epoch 330/500
# 11/11 [==============================] - 2s 147ms/step - loss: 0.0406 - accuracy: 0.9756 - val_loss: 0.0077 - val_accuracy: 1.0000
# ...
# Epoch 391/500
# 11/11 [==============================] - 2s 154ms/step - loss: 0.0279 - accuracy: 0.9878 - val_loss: 0.0048 - val_accuracy: 1.0000
# Epoch 392/500
# 11/11 [==============================] - 2s 146ms/step - loss: 0.0352 - accuracy: 0.9756 - val_loss: 0.0042 - val_accuracy: 1.0000
# Epoch 393/500
# 11/11 [==============================] - 2s 146ms/step - loss: 0.0498 - accuracy: 0.9756 - val_loss: 0.0057 - val_accuracy: 1.0000
# Epoch 394/500
# 11/11 [==============================] - 2s 146ms/step - loss: 0.1177 - accuracy: 0.9634 - val_loss: 0.0099 - val_accuracy: 1.0000
# Epoch 395/500
# 11/11 [==============================] - 2s 149ms/step - loss: 0.0173 - accuracy: 0.9878 - val_loss: 0.0128 - val_accuracy: 1.0000
# Epoch 396/500
# 11/11 [==============================] - 2s 148ms/step - loss: 0.0592 - accuracy: 0.9634 - val_loss: 0.0106 - val_accuracy: 1.0000
# Epoch 397/500
# 11/11 [==============================] - 2s 147ms/step - loss: 0.0553 - accuracy: 0.9756 - val_loss: 0.0083 - val_accuracy: 1.0000
# Epoch 398/500
# 11/11 [==============================] - 2s 150ms/step - loss: 0.0445 - accuracy: 0.9773 - val_loss: 0.0081 - val_accuracy: 1.0000
# Epoch 399/500
# 11/11 [==============================] - 2s 148ms/step - loss: 0.0507 - accuracy: 0.9756 - val_loss: 0.0078 - val_accuracy: 1.0000
# Epoch 400/500
# 11/11 [==============================] - 2s 147ms/step - loss: 0.0467 - accuracy: 0.9756 - val_loss: 0.0073 - val_accuracy: 1.0000
# Epoch 401/500
# 11/11 [==============================] - 2s 148ms/step - loss: 0.0368 - accuracy: 0.9756 - val_loss: 0.0064 - val_accuracy: 1.0000
# Epoch 402/500
# 11/11 [==============================] - 2s 149ms/step - loss: 0.0140 - accuracy: 0.9878 - val_loss: 0.0086 - val_accuracy: 1.0000
# Epoch 403/500
# 11/11 [==============================] - 2s 147ms/step - loss: 0.0704 - accuracy: 0.9756 - val_loss: 0.0061 - val_accuracy: 1.0000
# Epoch 404/500
# 11/11 [==============================] - 2s 155ms/step - loss: 0.0435 - accuracy: 0.9878 - val_loss: 0.0060 - val_accuracy: 1.0000
# Epoch 405/500
# 11/11 [==============================] - 2s 150ms/step - loss: 0.0662 - accuracy: 0.9756 - val_loss: 0.0093 - val_accuracy: 1.0000
# Epoch 406/500
# 11/11 [==============================] - 2s 149ms/step - loss: 0.0340 - accuracy: 0.9756 - val_loss: 0.0140 - val_accuracy: 1.0000
# Epoch 407/500
# 11/11 [==============================] - 2s 146ms/step - loss: 0.0270 - accuracy: 0.9878 - val_loss: 0.0118 - val_accuracy: 1.0000
# Epoch 408/500
# 11/11 [==============================] - 2s 147ms/step - loss: 0.0412 - accuracy: 0.9634 - val_loss: 0.0075 - val_accuracy: 1.0000
# Epoch 409/500
# 11/11 [==============================] - 2s 150ms/step - loss: 0.0498 - accuracy: 0.9773 - val_loss: 0.0057 - val_accuracy: 1.0000
# Epoch 410/500
# 11/11 [==============================] - 2s 147ms/step - loss: 0.0415 - accuracy: 0.9756 - val_loss: 0.0046 - val_accuracy: 1.0000
# Epoch 411/500
# 11/11 [==============================] - 2s 147ms/step - loss: 0.0379 - accuracy: 0.9634 - val_loss: 0.0054 - val_accuracy: 1.0000
# Epoch 412/500
# 11/11 [==============================] - 2s 146ms/step - loss: 0.0529 - accuracy: 0.9756 - val_loss: 0.0067 - val_accuracy: 1.0000
# Epoch 413/500
# 11/11 [==============================] - 2s 146ms/step - loss: 0.0371 - accuracy: 0.9878 - val_loss: 0.0070 - val_accuracy: 1.0000
# Epoch 414/500
# 11/11 [==============================] - 2s 152ms/step - loss: 0.0302 - accuracy: 0.9773 - val_loss: 0.0090 - val_accuracy: 1.0000
# Epoch 415/500
# 11/11 [==============================] - 2s 147ms/step - loss: 0.0567 - accuracy: 0.9634 - val_loss: 0.0171 - val_accuracy: 1.0000
# Epoch 416/500
# 11/11 [==============================] - 2s 151ms/step - loss: 0.0494 - accuracy: 0.9756 - val_loss: 0.0199 - val_accuracy: 1.0000
# Epoch 417/500
# 11/11 [==============================] - 2s 150ms/step - loss: 0.0517 - accuracy: 0.9634 - val_loss: 0.0134 - val_accuracy: 1.0000
# Epoch 418/500
# 11/11 [==============================] - 2s 147ms/step - loss: 0.0233 - accuracy: 0.9878 - val_loss: 0.0079 - val_accuracy: 1.0000
# Epoch 419/500
# 11/11 [==============================] - 2s 147ms/step - loss: 0.0945 - accuracy: 0.9756 - val_loss: 0.0117 - val_accuracy: 1.0000
# Epoch 420/500
# 11/11 [==============================] - 2s 145ms/step - loss: 0.0442 - accuracy: 0.9634 - val_loss: 0.0130 - val_accuracy: 1.0000
# Epoch 421/500
# 11/11 [==============================] - 2s 154ms/step - loss: 0.0488 - accuracy: 0.9634 - val_loss: 0.0154 - val_accuracy: 1.0000
# Epoch 422/500
# 11/11 [==============================] - 2s 146ms/step - loss: 0.0365 - accuracy: 0.9756 - val_loss: 0.0221 - val_accuracy: 1.0000
# Epoch 423/500
# 11/11 [==============================] - 2s 150ms/step - loss: 0.0364 - accuracy: 0.9773 - val_loss: 0.0255 - val_accuracy: 1.0000
# Epoch 424/500
# 11/11 [==============================] - 2s 154ms/step - loss: 0.0676 - accuracy: 0.9756 - val_loss: 0.0223 - val_accuracy: 1.0000
# Epoch 425/500
# 11/11 [==============================] - 2s 146ms/step - loss: 0.0668 - accuracy: 0.9878 - val_loss: 0.0177 - val_accuracy: 1.0000
# Epoch 426/500
# 11/11 [==============================] - 2s 150ms/step - loss: 0.0580 - accuracy: 0.9773 - val_loss: 0.0087 - val_accuracy: 1.0000
# Epoch 427/500
# 11/11 [==============================] - 2s 146ms/step - loss: 0.0591 - accuracy: 0.9634 - val_loss: 0.0082 - val_accuracy: 1.0000
# Epoch 428/500
# 11/11 [==============================] - 2s 146ms/step - loss: 0.0705 - accuracy: 0.9634 - val_loss: 0.0144 - val_accuracy: 1.0000
# Epoch 429/500
# 11/11 [==============================] - 2s 149ms/step - loss: 0.0210 - accuracy: 0.9878 - val_loss: 0.0308 - val_accuracy: 1.0000
# Epoch 430/500
# 11/11 [==============================] - 2s 147ms/step - loss: 0.0446 - accuracy: 0.9756 - val_loss: 0.0354 - val_accuracy: 0.9565
# Epoch 431/500
# 11/11 [==============================] - 2s 148ms/step - loss: 0.0418 - accuracy: 0.9756 - val_loss: 0.0250 - val_accuracy: 1.0000
# Epoch 432/500
# 11/11 [==============================] - 2s 148ms/step - loss: 0.0413 - accuracy: 0.9756 - val_loss: 0.0132 - val_accuracy: 1.0000
# Epoch 433/500
# 11/11 [==============================] - 2s 147ms/step - loss: 0.0330 - accuracy: 0.9878 - val_loss: 0.0114 - val_accuracy: 1.0000
# Epoch 434/500
# 11/11 [==============================] - 2s 147ms/step - loss: 0.0120 - accuracy: 1.0000 - val_loss: 0.0133 - val_accuracy: 1.0000
# Epoch 435/500
# 11/11 [==============================] - 2s 149ms/step - loss: 0.0639 - accuracy: 0.9756 - val_loss: 0.0113 - val_accuracy: 1.0000
# Epoch 436/500
# 11/11 [==============================] - 2s 147ms/step - loss: 0.0463 - accuracy: 0.9756 - val_loss: 0.0083 - val_accuracy: 1.0000
# Epoch 437/500
# 11/11 [==============================] - 2s 149ms/step - loss: 0.0501 - accuracy: 0.9878 - val_loss: 0.0080 - val_accuracy: 1.0000
# Epoch 438/500
# 11/11 [==============================] - 2s 147ms/step - loss: 0.0542 - accuracy: 0.9634 - val_loss: 0.0090 - val_accuracy: 1.0000
# Epoch 439/500
# 11/11 [==============================] - 2s 147ms/step - loss: 0.0475 - accuracy: 0.9634 - val_loss: 0.0185 - val_accuracy: 1.0000
# Epoch 440/500
# 11/11 [==============================] - 2s 146ms/step - loss: 0.0286 - accuracy: 0.9878 - val_loss: 0.0231 - val_accuracy: 1.0000
# Epoch 441/500
# 11/11 [==============================] - 2s 151ms/step - loss: 0.0517 - accuracy: 0.9659 - val_loss: 0.0117 - val_accuracy: 1.0000
# Epoch 442/500
# 11/11 [==============================] - 2s 149ms/step - loss: 0.0243 - accuracy: 0.9756 - val_loss: 0.0118 - val_accuracy: 1.0000
# Epoch 443/500
# 11/11 [==============================] - 2s 147ms/step - loss: 0.0415 - accuracy: 0.9878 - val_loss: 0.0116 - val_accuracy: 1.0000
# Epoch 444/500
# 11/11 [==============================] - 2s 147ms/step - loss: 0.0690 - accuracy: 0.9634 - val_loss: 0.0118 - val_accuracy: 1.0000
# Epoch 445/500
# 11/11 [==============================] - 2s 148ms/step - loss: 0.0360 - accuracy: 0.9756 - val_loss: 0.0121 - val_accuracy: 1.0000
# Epoch 446/500
# 11/11 [==============================] - 2s 149ms/step - loss: 0.0279 - accuracy: 0.9878 - val_loss: 0.0116 - val_accuracy: 1.0000
# Epoch 447/500
# 11/11 [==============================] - 2s 148ms/step - loss: 0.0560 - accuracy: 0.9756 - val_loss: 0.0477 - val_accuracy: 0.9565
# Epoch 448/500
# 11/11 [==============================] - 2s 151ms/step - loss: 0.0580 - accuracy: 0.9634 - val_loss: 0.0723 - val_accuracy: 0.9565
# Epoch 449/500
# 11/11 [==============================] - 2s 148ms/step - loss: 0.0296 - accuracy: 0.9756 - val_loss: 0.0914 - val_accuracy: 0.9565
# Epoch 450/500
# 11/11 [==============================] - 2s 150ms/step - loss: 0.0447 - accuracy: 0.9756 - val_loss: 0.0936 - val_accuracy: 0.9565
# Epoch 451/500
# 11/11 [==============================] - 2s 147ms/step - loss: 0.0297 - accuracy: 0.9878 - val_loss: 0.0845 - val_accuracy: 0.9565
# Epoch 452/500
# 11/11 [==============================] - 2s 149ms/step - loss: 0.0499 - accuracy: 0.9634 - val_loss: 0.0486 - val_accuracy: 0.9565
# Epoch 453/500
# 11/11 [==============================] - 2s 145ms/step - loss: 0.0592 - accuracy: 0.9634 - val_loss: 0.0399 - val_accuracy: 0.9565
# Epoch 454/500
# 11/11 [==============================] - 2s 149ms/step - loss: 0.0574 - accuracy: 0.9756 - val_loss: 0.0149 - val_accuracy: 1.0000
# Epoch 455/500
# 11/11 [==============================] - 2s 149ms/step - loss: 0.0428 - accuracy: 0.9756 - val_loss: 0.0142 - val_accuracy: 1.0000
# Epoch 456/500
# 11/11 [==============================] - 2s 147ms/step - loss: 0.0377 - accuracy: 0.9878 - val_loss: 0.0094 - val_accuracy: 1.0000
# Epoch 457/500
# 11/11 [==============================] - 2s 157ms/step - loss: 0.0242 - accuracy: 1.0000 - val_loss: 0.0172 - val_accuracy: 1.0000
# Epoch 458/500
# 11/11 [==============================] - 2s 152ms/step - loss: 0.0547 - accuracy: 0.9634 - val_loss: 0.0223 - val_accuracy: 1.0000
# Epoch 459/500
# 11/11 [==============================] - 2s 150ms/step - loss: 0.0345 - accuracy: 0.9756 - val_loss: 0.0253 - val_accuracy: 1.0000
# Epoch 460/500
# 11/11 [==============================] - 2s 149ms/step - loss: 0.0598 - accuracy: 0.9878 - val_loss: 0.0231 - val_accuracy: 1.0000
# Epoch 461/500
# 11/11 [==============================] - 2s 150ms/step - loss: 0.0184 - accuracy: 0.9878 - val_loss: 0.0174 - val_accuracy: 1.0000
# Epoch 462/500
# 11/11 [==============================] - 2s 150ms/step - loss: 0.0376 - accuracy: 0.9756 - val_loss: 0.0149 - val_accuracy: 1.0000
# Epoch 463/500
# 11/11 [==============================] - 2s 149ms/step - loss: 0.0520 - accuracy: 0.9756 - val_loss: 0.0154 - val_accuracy: 1.0000
# Epoch 464/500
# 11/11 [==============================] - 2s 157ms/step - loss: 0.0582 - accuracy: 0.9756 - val_loss: 0.0094 - val_accuracy: 1.0000
# Epoch 465/500
# 11/11 [==============================] - 2s 149ms/step - loss: 0.0365 - accuracy: 0.9634 - val_loss: 0.0121 - val_accuracy: 1.0000
# Epoch 466/500
# 11/11 [==============================] - 2s 148ms/step - loss: 0.0262 - accuracy: 0.9878 - val_loss: 0.0129 - val_accuracy: 1.0000
# Epoch 467/500
# 11/11 [==============================] - 2s 149ms/step - loss: 0.0720 - accuracy: 0.9756 - val_loss: 0.0126 - val_accuracy: 1.0000
# Epoch 468/500
# 11/11 [==============================] - 2s 152ms/step - loss: 0.0363 - accuracy: 0.9659 - val_loss: 0.0131 - val_accuracy: 1.0000
# Epoch 469/500
# 11/11 [==============================] - 2s 150ms/step - loss: 0.0462 - accuracy: 0.9634 - val_loss: 0.0190 - val_accuracy: 1.0000
# Epoch 470/500
# 11/11 [==============================] - 2s 151ms/step - loss: 0.0347 - accuracy: 0.9756 - val_loss: 0.0210 - val_accuracy: 1.0000
# Epoch 471/500
# 11/11 [==============================] - 2s 152ms/step - loss: 0.0279 - accuracy: 0.9756 - val_loss: 0.0248 - val_accuracy: 1.0000
# Epoch 472/500
# 11/11 [==============================] - 2s 151ms/step - loss: 0.0583 - accuracy: 0.9756 - val_loss: 0.0144 - val_accuracy: 1.0000
# Epoch 473/500
# 11/11 [==============================] - 2s 159ms/step - loss: 0.0564 - accuracy: 0.9634 - val_loss: 0.0127 - val_accuracy: 1.0000
# Epoch 474/500
# 11/11 [==============================] - 2s 151ms/step - loss: 0.0561 - accuracy: 0.9634 - val_loss: 0.0271 - val_accuracy: 1.0000
# Epoch 475/500
# 11/11 [==============================] - 2s 149ms/step - loss: 0.0386 - accuracy: 0.9756 - val_loss: 0.0397 - val_accuracy: 0.9565
# Epoch 476/500
# 11/11 [==============================] - 2s 150ms/step - loss: 0.0365 - accuracy: 0.9878 - val_loss: 0.0383 - val_accuracy: 0.9565
# Epoch 477/500
# 11/11 [==============================] - 2s 148ms/step - loss: 0.0526 - accuracy: 0.9756 - val_loss: 0.0278 - val_accuracy: 1.0000
# Epoch 478/500
# 11/11 [==============================] - 2s 149ms/step - loss: 0.0556 - accuracy: 0.9634 - val_loss: 0.0156 - val_accuracy: 1.0000
# Epoch 479/500
# 11/11 [==============================] - 2s 148ms/step - loss: 0.0444 - accuracy: 0.9756 - val_loss: 0.0081 - val_accuracy: 1.0000
# Epoch 480/500
# 11/11 [==============================] - 2s 149ms/step - loss: 0.0446 - accuracy: 0.9756 - val_loss: 0.0064 - val_accuracy: 1.0000
# Epoch 481/500
# 11/11 [==============================] - 2s 150ms/step - loss: 0.0457 - accuracy: 0.9634 - val_loss: 0.0059 - val_accuracy: 1.0000
# Epoch 482/500
# 11/11 [==============================] - 2s 149ms/step - loss: 0.0424 - accuracy: 0.9756 - val_loss: 0.0060 - val_accuracy: 1.0000
# Epoch 483/500
# 11/11 [==============================] - 2s 150ms/step - loss: 0.0358 - accuracy: 0.9878 - val_loss: 0.0065 - val_accuracy: 1.0000
# Epoch 484/500
# 11/11 [==============================] - 2s 149ms/step - loss: 0.0434 - accuracy: 0.9634 - val_loss: 0.0058 - val_accuracy: 1.0000
# Epoch 485/500
# 11/11 [==============================] - 2s 148ms/step - loss: 0.0344 - accuracy: 0.9756 - val_loss: 0.0058 - val_accuracy: 1.0000
# Epoch 486/500
# 11/11 [==============================] - 2s 147ms/step - loss: 0.0679 - accuracy: 0.9756 - val_loss: 0.0058 - val_accuracy: 1.0000
# Epoch 487/500
# 11/11 [==============================] - 2s 152ms/step - loss: 0.0406 - accuracy: 0.9659 - val_loss: 0.0067 - val_accuracy: 1.0000
# Epoch 488/500
# 11/11 [==============================] - 2s 147ms/step - loss: 0.0344 - accuracy: 0.9756 - val_loss: 0.0067 - val_accuracy: 1.0000
# Epoch 489/500
# 11/11 [==============================] - 2s 151ms/step - loss: 0.0331 - accuracy: 1.0000 - val_loss: 0.0069 - val_accuracy: 1.0000
# Epoch 490/500
# 11/11 [==============================] - 2s 148ms/step - loss: 0.0448 - accuracy: 0.9756 - val_loss: 0.0324 - val_accuracy: 0.9565
# Epoch 491/500
# 11/11 [==============================] - 2s 152ms/step - loss: 0.0370 - accuracy: 0.9886 - val_loss: 0.0290 - val_accuracy: 1.0000
# Epoch 492/500
# 11/11 [==============================] - 2s 148ms/step - loss: 0.0463 - accuracy: 0.9634 - val_loss: 0.0268 - val_accuracy: 1.0000
# Epoch 493/500
# 11/11 [==============================] - 2s 148ms/step - loss: 0.0451 - accuracy: 0.9756 - val_loss: 0.0589 - val_accuracy: 0.9565
# Epoch 494/500
# 11/11 [==============================] - 2s 146ms/step - loss: 0.0478 - accuracy: 0.9756 - val_loss: 0.0540 - val_accuracy: 0.9565
# Epoch 495/500
# 11/11 [==============================] - 2s 148ms/step - loss: 0.0235 - accuracy: 0.9878 - val_loss: 0.0681 - val_accuracy: 0.9565
# Epoch 496/500
# 11/11 [==============================] - 2s 147ms/step - loss: 0.0457 - accuracy: 0.9634 - val_loss: 0.0297 - val_accuracy: 1.0000
# Epoch 497/500
# 11/11 [==============================] - 2s 149ms/step - loss: 0.0453 - accuracy: 0.9634 - val_loss: 0.0504 - val_accuracy: 0.9565
# Epoch 498/500
# 11/11 [==============================] - 2s 148ms/step - loss: 0.0516 - accuracy: 0.9634 - val_loss: 0.0107 - val_accuracy: 1.0000
# Epoch 499/500
# 11/11 [==============================] - 2s 146ms/step - loss: 0.0357 - accuracy: 0.9756 - val_loss: 0.0119 - val_accuracy: 1.0000
# Epoch 500/500
# 11/11 [==============================] - 2s 156ms/step - loss: 0.0301 - accuracy: 0.9878 - val_loss: 0.0110 - val_accuracy: 1.0000

# %%
#making predictions on the testing data
predIndexs = model.predict(testX, batch_size=batchSize)

"""for each image in the testing data we need to find the index of the
   label with corresponding largest predicted probability"""
predIndexs = np.argmax(predIndexs, axis=1)

#printing classification report
print(classification_report(testY.argmax(axis=1), predIndexs, target_names=lb.classes_))
# Out:
#               precision    recall  f1-score   support
#
#     infected       1.00      1.00      1.00        13
#   uninfected       1.00      1.00      1.00        10
#
#     accuracy                           1.00        23
#    macro avg       1.00      1.00      1.00        23
# weighted avg       1.00      1.00      1.00        23

# %%
#computing the confusion matrix and use it to derive the raw accuracy
cm = confusion_matrix(testY.argmax(axis=1), predIndexs)
total = sum(sum(cm))
acc = (cm[0, 0] + cm[1, 1]) / total

# printing confusion matrix, accuracy
print(cm)
print("acc: {:.4f}".format(acc))
# Out:
# [[13  0]
#  [ 0 10]]
# acc: 1.0000

# %%
import itertools
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
class_names = ["Covid-19","Normal"]

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap="plasma"):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="red" if cm[i, j] > thresh else "blue")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
from matplotlib.font_manager import FontProperties

def plot_cm(labels, predictions):
    '''
    Plot the confusion matrix
    '''

    font = FontProperties()
    font.set_family('serif')
    font.set_name('Times New Roman')
    # font.set_style('italic')

    print(classification_report(labels, predictions, target_names=['Normal', 'Covid-19'], digits=3))

    cm = confusion_matrix(labels, predictions)
    print()

    plt.figure(figsize=(8,8))
    sns.heatmap(cm, annot=True, fmt="d", annot_kws={"size": 20})
    plt.yticks(fontsize=15)
    plt.xticks(fontsize=15)
    plt.title('Confusion Matrix',fontsize=30, fontweight='bold')
    plt.ylabel('Actual Label', fontsize=20)
    plt.xlabel('Predicted Label: Normal (0), Covid-19 (1)', fontsize=20)

# %%
import seaborn as sns
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
#plt.figure()
plt.figure(figsize=(8,8))
sns.heatmap(cm, annot=True, fmt="d", annot_kws={"size": 20})
#plot_confusion_matrix(cm, classes=class_names,
                      #title='Confusion matrix for Covid-19 Detection',cmap="plasma
plt.yticks(fontsize=15)
plt.xticks(fontsize=15)
plt.title('Confusion Matrix',fontsize=30, fontweight='bold')
plt.ylabel('Actual Label', fontsize=20)
plt.xlabel('Predicted Label: Normal (0), Covid-19 (1)', fontsize=20)
plt.savefig('confusion_matrix.pdf', format='pdf')

# %% [markdown]
# **List all data in history**

# %%
history = networkHead
print(history.history.keys())
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %% [markdown]
# **Summarize history for accuracy**

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# **Summarize history for loss**

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
# plot the training loss and accuracy
N = epochs
plt.style.use("ggplot")
plt.figure()
plt.plot(np.arange(0, N), networkHead.history["loss"], label="train_loss")
plt.plot(np.arange(0, N), networkHead.history["val_loss"], label="val_loss")
plt.plot(np.arange(0, N), networkHead.history["accuracy"], label="train_acc")
plt.plot(np.arange(0, N), networkHead.history["val_accuracy"], label="val_acc")
plt.title("Training Loss and Accuracy on COVID-19 Dataset")
plt.xlabel("Epoch #")
plt.ylabel("Loss/Accuracy")
plt.legend(loc="lower left")
plt.show()
plt.savefig("plot.png")

# %%
#saving the model
model.save(args["model"])
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/tracking/tracking.py:111: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/tracking/tracking.py:111: Layer.updates (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# INFO:tensorflow:Assets written to: corona.model/assets

# %%
# !ls
# Out:
# confusion_matrix.pdf	    DenseNet201_COVID_19.ipynb	train_model.ipynb
# corona.model		    output			VGG16_COVID_19.ipynb
# dataset			    plot.png			VGG19_COVID_19.ipynb
# DenseNet121_COVID_19.ipynb  README.md			Wazir_first_model.png
# DenseNet169_COVID_19.ipynb  ResNet101_COVID_19.ipynb	Xception_COVID_19.ipynb

# %%
#testing out the model
import tensorflow as tf

#loading the model
model = tf.keras.models.load_model("corona.model")

# %%
testImage = cv2.imread("./dataset/infected/A.jpeg") #For Positive Case
#testImage = cv2.imread("./dataset/infected/B.jpeg") #For Negative Case

# %%
#preprocessing the test image
image = cv2.cvtColor(testImage, cv2.COLOR_BGR2RGB)
image = cv2.resize(image, (224, 224))
image = image.astype("float") / 255.0

# %%
#reshaping the numpy array according to image size
image = np.array(image).reshape(1,224,224,3)

#doing prediction on test image
pred = model.predict(image)
pred = pred.argmax(axis=1)[0]

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

# %%
#putting text on image and showing output image
imageText = "Corona Negative" if pred == 1 else "Corona Positive"
color = (0, 255, 0) if pred == 1 else (0, 0, 255)

testImage = cv2.resize(testImage, (424, 424))
cv2.putText(testImage, imageText, (3, 20), cv2.FONT_ITALIC, 0.5,color, 2)
cv2_imshow(testImage)
# Out:
# <PIL.Image.Image image mode=RGB size=424x424 at 0x7F2978B14320>
